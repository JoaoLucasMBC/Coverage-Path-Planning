# %%
import numpy as np
import gymnasium as gym
import random
from gymnasium import spaces
from collections import deque

# %%
def bfs_reachable(grid, start, targets):
    """
    Check if all target cells are reachable from start on grid (0=free, 1=obstacle).
    """
    H, W = grid.shape
    visited = np.zeros_like(grid, dtype=bool)
    queue = deque([start])
    visited[start] = True
    reached = set()
    while queue:
        i, j = queue.popleft()
        if (i, j) in targets:
            reached.add((i, j))
            if reached == set(targets):
                return True
        for di, dj in ((1,0),(-1,0),(0,1),(0,-1)):
            ni, nj = i+di, j+dj
            if 0 <= ni < H and 0 <= nj < W and not visited[ni, nj] and grid[ni, nj] == 0:
                visited[ni, nj] = True
                queue.append((ni, nj))
    return False

# %%
class CoverageEnv(gym.Env):
    metadata = {"render.modes": ["human"]}

    def __init__(self, max_steps=200, seed=None):
        super().__init__()
        self.H, self.W = 8, 8
        self.max_steps = max_steps

        # seeding for reproducibility
        self.seed(seed)

        # Action: down, up, right, left
        self.action_space = spaces.Discrete(4)
        self.observation_space = spaces.Box(0.0, 1.0, shape=(5, self.H, self.W), dtype=np.float32)

        # Define a fixed shape library
        self.shape_library = [
            np.array([[1]]),                # single cell
            np.ones((1,3), dtype=int),     # horizontal bar
            np.ones((2,2), dtype=int),     # 2x2 block
            np.array([[1,1,1],             # U-shape
                      [1,0,1],
                      [1,1,1]]),
            np.array([[1,1,0],             # L-shape
                      [1,0,0]])
        ]

    def seed(self, seed=None):
        """
        Seed the environment's RNGs for reproducible layouts.
        """
        np.random.seed(seed)
        random.seed(seed)
        return [seed]

    def reset(self, *, seed=None, options=None):
        """
        Reset the environment; returns obs (shape C×H×W), info
        Channels:
         0 = free space
         1 = obstacles
         2 = agent location
         3 = target area
         4 = visited mask (all zeros at reset)
        """

        if seed is not None:
            self.seed(42)
        else: 
            self.seed(42)


        while True:
            grid = np.zeros((self.H, self.W), dtype=int)

            num_shapes = np.random.randint(1, len(self.shape_library) + 1)

            allowed = random.sample(self.shape_library, num_shapes)

            placed = np.zeros_like(grid)
            for _ in range(num_shapes):
                shape = random.choice(allowed)
                sh, sw = shape.shape
                i = np.random.randint(0, self.H - sh + 1)
                j = np.random.randint(0, self.W - sw + 1)
                if not np.any(placed[i:i+sh, j:j+sw] & shape):
                    placed[i:i+sh, j:j+sw] |= shape
            grid = placed

            ti = np.random.randint(0, self.H - 3 + 1)
            tj = np.random.randint(0, self.W - 3 + 1)
            full_block = [(ti+di, tj+dj) for di in range(3) for dj in range(3)]
            targets = [(i,j) for (i,j) in full_block if grid[i,j] == 0]
            if not targets:
                continue

            free_cells = list(zip(*np.where(grid == 0)))
            start = random.choice(free_cells)
            if bfs_reachable(grid, start, targets):
                break

        self.grid = grid
        self.targets = set(targets)
        self.agent_pos = start
        self.visited = { start }
        self.steps = 0

        return self._get_obs(), {}

    def _get_obs(self):
        C = 5
        state = np.zeros((C, self.H, self.W), dtype=np.float32)

        # channel 0: free space (grid==0)
        state[0, :, :] = (self.grid == 0).astype(np.float32)
        # channel 1: obstacles (grid!=0)
        state[1, :, :] = (self.grid != 0).astype(np.float32)
        # channel 2: agent location
        i, j = self.agent_pos
        state[2, i, j] = 1.0
        # channel 3: target area
        for (ti, tj) in self.targets:
            state[3, ti, tj] = 1.0
        for vi, vj in self.visited:
            state[4, vi, vj] = 1.0
        
        return state

    def step(self, action):
        # Define movement vectors
        # 0 = down, 1 = up, 2 = right, 3 = left
        moves = {0: (1, 0), 1: (-1, 0), 2: (0, 1), 3: (0, -1)}
        i, j = self.agent_pos
        di, dj = moves[action]
        ni, nj = i + di, j + dj

        # Default baseline reward
        reward = 0

        # Check validity and apply penalties
        if not (0 <= ni < self.H and 0 <= nj < self.W and self.grid[ni, nj] == 0):
            # Invalid action: stay in place
            self.agent_pos = (i, j) 
        else:
            # Valid move: update position
            self.agent_pos = (ni, nj)

        # Check if on a target
        if self.agent_pos not in self.visited:
            if self.agent_pos in self.targets:
                reward = 2.0   # new target
            self.visited.add(self.agent_pos)
        else:
            reward = -1

        # Step count
        self.steps += 1

        # Terminal bonus
        terminated = True
        for (i,j) in self.targets:
            if (i,j) not in self.visited:
                terminated = False
                break
            
        truncated = (self.steps >= self.max_steps)
        if terminated:
            reward += 30.0

        return self._get_obs(), reward, terminated, truncated, {}

    def render(self, mode="human"):
        disp = np.full((self.H, self.W), '.', dtype=str)
        for (i,j) in self.targets:
            disp[i,j] = 'T'
        for (i,j) in zip(*np.where(self.grid == 1)):
            disp[i,j] = '#'
        ai, aj = self.agent_pos
        disp[ai, aj] = 'A'
        print("\n".join("".join(row) for row in disp))
        print("\n")

    def close(self):
        pass

# %%
gym.register(
    id="Coverage-v0",
    entry_point="coverage_env:CoverageEnv",
    max_episode_steps=200,
)
# Out:
# /Users/pedropertusi/Desktop/reinforcement-learning/Coverage-Path-Planning/env/lib/python3.12/site-packages/gymnasium/envs/registration.py:642: UserWarning: WARN: Overriding environment Coverage-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

# instantiate a single env (you can wrap VecEnv for parallelism later)
env = CoverageEnv(seed=42)

# create the DQN model
model = DQN(
    policy="MlpPolicy",   # a simple MLP
    env=env,
    buffer_size=100000,
    learning_rate=1e-4,
    batch_size=32,
    gamma=0.99,
    verbose=1,
)

# train for 50k timesteps
model.learn(total_timesteps=500_000)

# save it
model.save("dqn_coverage")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4504     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 662      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0752   |
# |    n_updates        | 140      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4642     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1462     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0258   |
# |    n_updates        | 340      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4681     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2249     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13     |
# |    n_updates        | 537      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | -150     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4717     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2995     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.112    |
# |    n_updates        | 723      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -139     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4437     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3592     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0603   |
# |    n_updates        | 872      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4468     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4257     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0863   |
# |    n_updates        | 1039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 4495     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4977     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.138    |
# |    n_updates        | 1219     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | -130     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4515     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5664     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.07     |
# |    n_updates        | 1390     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | -131     |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4518     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6443     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0862   |
# |    n_updates        | 1585     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 4526     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7145     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.23     |
# |    n_updates        | 1761     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 4525     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7903     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.161    |
# |    n_updates        | 1950     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | -124     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4520     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8427     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.25     |
# |    n_updates        | 2081     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4512     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8893     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0977   |
# |    n_updates        | 2198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4477     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9498     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 2349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4457     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10288    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0461   |
# |    n_updates        | 2546     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | -112     |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4452     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10663    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.23     |
# |    n_updates        | 2640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | -112     |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 4453     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11315    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13     |
# |    n_updates        | 2803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 165      |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 4452     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11887    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.054    |
# |    n_updates        | 2946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.764    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4451     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12406    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.095    |
# |    n_updates        | 3076     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | -105     |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4448     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12883    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.214    |
# |    n_updates        | 3195     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4447     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 13528    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0578   |
# |    n_updates        | 3356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 162      |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4446     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 14264    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.162    |
# |    n_updates        | 3540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 162      |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.717    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4442     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 14894    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.062    |
# |    n_updates        | 3698     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.703    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 4432     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15643    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.193    |
# |    n_updates        | 3885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 162      |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.693    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4428     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16183    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.172    |
# |    n_updates        | 4020     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | -103     |
# |    exploration_rate | 0.682    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4418     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16733    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 4158     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | -102     |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4407     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17522    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0681   |
# |    n_updates        | 4355     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | -100     |
# |    exploration_rate | 0.654    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4403     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18208    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0569   |
# |    n_updates        | 4526     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | -96.4    |
# |    exploration_rate | 0.645    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 4400     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18668    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.115    |
# |    n_updates        | 4641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | -95      |
# |    exploration_rate | 0.636    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 4396     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19151    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.124    |
# |    n_updates        | 4762     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -94.4    |
# |    exploration_rate | 0.625    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4390     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19758    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0316   |
# |    n_updates        | 4914     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | -90.6    |
# |    exploration_rate | 0.616    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4386     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 20204    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.115    |
# |    n_updates        | 5025     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 147      |
# |    ep_rew_mean      | -85.5    |
# |    exploration_rate | 0.612    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4383     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 20401    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.123    |
# |    n_updates        | 5075     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | -83.6    |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 4380     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 21018    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.211    |
# |    n_updates        | 5229     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 145      |
# |    ep_rew_mean      | -82.8    |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 4376     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 21630    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0972   |
# |    n_updates        | 5382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | -79.5    |
# |    exploration_rate | 0.579    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 4344     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 22147    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.124    |
# |    n_updates        | 5511     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | -81.8    |
# |    exploration_rate | 0.567    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 4341     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 22807    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0524   |
# |    n_updates        | 5676     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | -82.5    |
# |    exploration_rate | 0.557    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 4338     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 23306    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0744   |
# |    n_updates        | 5801     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | -79      |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 4335     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 23590    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0381   |
# |    n_updates        | 5872     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | -76.3    |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 4332     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 24087    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.164    |
# |    n_updates        | 5996     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | -79.2    |
# |    exploration_rate | 0.531    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 4327     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 24686    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0587   |
# |    n_updates        | 6146     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -76.1    |
# |    exploration_rate | 0.524    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 4323     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 25043    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0226   |
# |    n_updates        | 6235     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -74.5    |
# |    exploration_rate | 0.516    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 4317     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 25464    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.1      |
# |    n_updates        | 6340     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -75.6    |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 4313     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 26096    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.165    |
# |    n_updates        | 6498     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -76.7    |
# |    exploration_rate | 0.494    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 4310     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 26617    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.106    |
# |    n_updates        | 6629     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | -73.1    |
# |    exploration_rate | 0.488    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 4308     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 26935    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.1      |
# |    n_updates        | 6708     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | -66.6    |
# |    exploration_rate | 0.486    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 4306     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 27065    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.128    |
# |    n_updates        | 6741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | -64.5    |
# |    exploration_rate | 0.478    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 4304     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 27486    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0905   |
# |    n_updates        | 6846     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | -61      |
# |    exploration_rate | 0.47     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 4300     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 27910    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.176    |
# |    n_updates        | 6952     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 122      |
# |    ep_rew_mean      | -60.3    |
# |    exploration_rate | 0.461    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 4296     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 28369    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.094    |
# |    n_updates        | 7067     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | -59.8    |
# |    exploration_rate | 0.452    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 4292     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 28841    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0453   |
# |    n_updates        | 7185     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -57.5    |
# |    exploration_rate | 0.441    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 4281     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 29424    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0454   |
# |    n_updates        | 7330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -54.6    |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 4279     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 29808    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.088    |
# |    n_updates        | 7426     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | -53.2    |
# |    exploration_rate | 0.428    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 4275     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 30110    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.127    |
# |    n_updates        | 7502     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -54.1    |
# |    exploration_rate | 0.418    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 4269     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 30638    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.122    |
# |    n_updates        | 7634     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -55.6    |
# |    exploration_rate | 0.405    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 4263     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 31342    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0732   |
# |    n_updates        | 7810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -56.2    |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 4259     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 31816    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0474   |
# |    n_updates        | 7928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -59.5    |
# |    exploration_rate | 0.387    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 4256     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 32288    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.344    |
# |    n_updates        | 8046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -59.1    |
# |    exploration_rate | 0.376    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 4252     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 32842    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 8185     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -57.8    |
# |    exploration_rate | 0.367    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 4247     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 33297    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0971   |
# |    n_updates        | 8299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -60.9    |
# |    exploration_rate | 0.353    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 4240     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 34027    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0825   |
# |    n_updates        | 8481     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -58.7    |
# |    exploration_rate | 0.343    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 4236     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 34559    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 8614     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -56.5    |
# |    exploration_rate | 0.337    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 4234     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 34908    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0796   |
# |    n_updates        | 8701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -59.5    |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 4229     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 35436    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0839   |
# |    n_updates        | 8833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | -60.1    |
# |    exploration_rate | 0.315    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 4223     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 36061    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0675   |
# |    n_updates        | 8990     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -56.8    |
# |    exploration_rate | 0.309    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 4220     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 36370    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0948   |
# |    n_updates        | 9067     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -55.7    |
# |    exploration_rate | 0.303    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 4218     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 36683    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0489   |
# |    n_updates        | 9145     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -57.5    |
# |    exploration_rate | 0.292    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 4214     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 37272    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0358   |
# |    n_updates        | 9292     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -57.8    |
# |    exploration_rate | 0.279    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 4207     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 37957    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0594   |
# |    n_updates        | 9464     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -58.5    |
# |    exploration_rate | 0.267    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 4201     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 38556    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.231    |
# |    n_updates        | 9613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 122      |
# |    ep_rew_mean      | -61.3    |
# |    exploration_rate | 0.256    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 4196     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 39140    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.313    |
# |    n_updates        | 9759     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 127      |
# |    ep_rew_mean      | -66.6    |
# |    exploration_rate | 0.245    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 4190     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 39762    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0304   |
# |    n_updates        | 9915     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | -65.8    |
# |    exploration_rate | 0.239    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 4187     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 40075    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.116    |
# |    n_updates        | 9993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | -66.5    |
# |    exploration_rate | 0.23     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 4183     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 40549    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.27     |
# |    n_updates        | 10112    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 124      |
# |    ep_rew_mean      | -64.4    |
# |    exploration_rate | 0.224    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 4180     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 40816    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.084    |
# |    n_updates        | 10178    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | -65.7    |
# |    exploration_rate | 0.213    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 4173     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 41415    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.177    |
# |    n_updates        | 10328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | -66.3    |
# |    exploration_rate | 0.201    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 4166     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 42037    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0389   |
# |    n_updates        | 10484    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | -68.2    |
# |    exploration_rate | 0.191    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 4163     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 42602    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0927   |
# |    n_updates        | 10625    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 131      |
# |    ep_rew_mean      | -71.8    |
# |    exploration_rate | 0.179    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 4157     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 43231    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0704   |
# |    n_updates        | 10782    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | -71      |
# |    exploration_rate | 0.17     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 4152     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 43682    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.113    |
# |    n_updates        | 10895    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 127      |
# |    ep_rew_mean      | -66.3    |
# |    exploration_rate | 0.164    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 4149     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 43999    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0758   |
# |    n_updates        | 10974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 127      |
# |    ep_rew_mean      | -66.8    |
# |    exploration_rate | 0.154    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 4143     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 44509    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0411   |
# |    n_updates        | 11102    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | -67.4    |
# |    exploration_rate | 0.144    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 4139     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 45063    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.127    |
# |    n_updates        | 11240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 127      |
# |    ep_rew_mean      | -66.9    |
# |    exploration_rate | 0.135    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 4134     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 45550    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.11     |
# |    n_updates        | 11362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -63.9    |
# |    exploration_rate | 0.131    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 4126     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 45748    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0359   |
# |    n_updates        | 11411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 124      |
# |    ep_rew_mean      | -63.5    |
# |    exploration_rate | 0.117    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 4119     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 46469    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16     |
# |    n_updates        | 11592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | -65.4    |
# |    exploration_rate | 0.105    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 4114     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 47128    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0372   |
# |    n_updates        | 11756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | -69.3    |
# |    exploration_rate | 0.0923   |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 4109     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 47773    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0474   |
# |    n_updates        | 11918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | -69.2    |
# |    exploration_rate | 0.0823   |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 4105     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 48301    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0436   |
# |    n_updates        | 12050    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | -69.8    |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 4100     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 48945    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.155    |
# |    n_updates        | 12211    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | -76      |
# |    exploration_rate | 0.0548   |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 4093     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 49745    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0734   |
# |    n_updates        | 12411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# ...
# |    time_elapsed     | 170      |
# |    total_timesteps  | 497431   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0027   |
# |    n_updates        | 124332   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 33.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16900    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 497510   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 124352   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 33.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16904    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 497588   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00534  |
# |    n_updates        | 124371   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 33.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16908    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 497739   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.341    |
# |    n_updates        | 124409   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 33.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16912    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 497809   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00715  |
# |    n_updates        | 124427   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 33.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16916    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 497891   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 124447   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 33       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16920    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 498002   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0348   |
# |    n_updates        | 124475   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 32.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16924    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 498163   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.137    |
# |    n_updates        | 124515   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 32.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16928    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 498240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00917  |
# |    n_updates        | 124534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 33       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16932    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 498317   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0865   |
# |    n_updates        | 124554   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 33       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16936    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 498389   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0089   |
# |    n_updates        | 124572   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 33       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16940    |
# |    fps              | 2920     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 498469   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0801   |
# |    n_updates        | 124592   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 33.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16944    |
# |    fps              | 2920     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 498547   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 124611   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 33.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16948    |
# |    fps              | 2920     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 498621   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 124630   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 33.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16952    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 498703   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 124650   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 33.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16956    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 498779   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.014    |
# |    n_updates        | 124669   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 33.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16960    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 498860   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 124689   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 33.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16964    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 498938   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 124709   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 33.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16968    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 499020   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 124729   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 33.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16972    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 499098   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00442  |
# |    n_updates        | 124749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 33.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16976    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 499178   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0122   |
# |    n_updates        | 124769   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 33.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16980    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 499258   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0387   |
# |    n_updates        | 124789   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 33.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16984    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 499340   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 124809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 33.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16988    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 499419   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 124829   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 33.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16992    |
# |    fps              | 2921     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 499498   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0111   |
# |    n_updates        | 124849   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 33.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16996    |
# |    fps              | 2921     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 499574   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 124868   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 33.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17000    |
# |    fps              | 2921     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 499651   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 124887   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 33.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17004    |
# |    fps              | 2921     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 499726   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.04     |
# |    n_updates        | 124906   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 34.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17008    |
# |    fps              | 2921     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 499801   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00511  |
# |    n_updates        | 124925   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 34.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17012    |
# |    fps              | 2921     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 499874   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 124943   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 34.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 17016    |
# |    fps              | 2921     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 499954   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.01     |
# |    n_updates        | 124963   |
# ----------------------------------

# %%
# load (if needed)
# model = DQN.load("dqn_coverage", env=env)

mean_reward, std_reward = evaluate_policy(
    model, 
    env, 
    n_eval_episodes=20, 
    deterministic=True,
)
print(f"Mean reward: {mean_reward:.2f} ± {std_reward:.2f}")
# Out:
# /Users/pedropertusi/Desktop/reinforcement-learning/Coverage-Path-Planning/env/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward: -187.60 ± 10.49

# %%
obs, _ = env.reset(seed=42)

for i in range(env.max_steps):
    # model.predict returns e.g. array([2], dtype=int64)
    action_arr, _ = model.predict(obs, deterministic=True)
    action = int(action_arr)       # unwrap to Python int
    print("step:", i, "action:", action)

    obs, reward, terminated, truncated, info = env.step(action)
    env.render()
    print("\n")

    if terminated or truncated:
        break
# Out:
# step: 0 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 1 action: 2
# .....A..
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 2 action: 3
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 3 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 4 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 5 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 6 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 7 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 8 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 9 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 10 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 11 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 12 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 13 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 14 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 15 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 16 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 17 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 18 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 19 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 20 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 21 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 22 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 23 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 24 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 25 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 26 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 27 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 28 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 29 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 30 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 31 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 32 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 33 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 34 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 35 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 36 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 37 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 38 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 39 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 40 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 41 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 42 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 43 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 44 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 45 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 46 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 47 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 48 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 49 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 50 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 51 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 52 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 53 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 54 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 55 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 56 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 57 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 58 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 59 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 60 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 61 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 62 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 63 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 64 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 65 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 66 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 67 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 68 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 69 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 70 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 71 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 72 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 73 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 74 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 75 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 76 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 77 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 78 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 79 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 80 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 81 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 82 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 83 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 84 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 85 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 86 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 87 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 88 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 89 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 90 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 91 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 92 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 93 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 94 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 95 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 96 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 97 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 98 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 99 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 100 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 101 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 102 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 103 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 104 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 105 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 106 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 107 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 108 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 109 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 110 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 111 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 112 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 113 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 114 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 115 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 116 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 117 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 118 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 119 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 120 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 121 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 122 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 123 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 124 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 125 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 126 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 127 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 128 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 129 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 130 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 131 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 132 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 133 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 134 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 135 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 136 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 137 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 138 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 139 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 140 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 141 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 142 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 143 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 144 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 145 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 146 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 147 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 148 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 149 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 150 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 151 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 152 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 153 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 154 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 155 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 156 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 157 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 158 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 159 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 160 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 161 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 162 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 163 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 164 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 165 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 166 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 167 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 168 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 169 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 170 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 171 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 172 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 173 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 174 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 175 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 176 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 177 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 178 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 179 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 180 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 181 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 182 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 183 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 184 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 185 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 186 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 187 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 188 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 189 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 190 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 191 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 192 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 193 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 194 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 195 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 196 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 197 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 198 action: 2
# ....A...
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
#
#
#
#
# step: 199 action: 3
# ...A....
# T##.#...
# T#T.....
# TTT.....
# ........
# ...###..
# ...#.#..
# ...###..
