# %%
import numpy as np
import gymnasium as gym
import random
from gymnasium import spaces
from collections import deque

# %%
def bfs_reachable(grid, start, targets):
    """
    Check if all target cells are reachable from start on grid (0=free, 1=obstacle).
    """
    H, W = grid.shape
    visited = np.zeros_like(grid, dtype=bool)
    queue = deque([start])
    visited[start] = True
    reached = set()
    while queue:
        i, j = queue.popleft()
        if (i, j) in targets:
            reached.add((i, j))
            if reached == set(targets):
                return True
        for di, dj in ((1,0),(-1,0),(0,1),(0,-1)):
            ni, nj = i+di, j+dj
            if 0 <= ni < H and 0 <= nj < W and not visited[ni, nj] and grid[ni, nj] == 0:
                visited[ni, nj] = True
                queue.append((ni, nj))
    return False

# %%
class CoverageEnv(gym.Env):
    metadata = {"render.modes": ["human"]}

    def __init__(self, curriculum_max=3, max_steps=200, seed=None):
        super().__init__()
        self.H, self.W = 8, 8
        self.curriculum_level = 0
        self.curriculum_max = curriculum_max
        self.max_steps = max_steps

        # seeding for reproducibility
        self.seed(seed)

        # Action: down, up, right, left
        self.action_space = spaces.Discrete(4)
        # Observation: flattened grid + agent pos + coverage mask
        obs_size = self.H * self.W + 2 + self.H * self.W
        self.observation_space = spaces.Box(0.0, 1.0, shape=(obs_size,), dtype=np.float32)

        # Define a fixed shape library
        self.shape_library = [
            np.array([[1]]),                # single cell
            np.ones((1,3), dtype=int),     # horizontal bar
            np.ones((2,2), dtype=int),     # 2x2 block
            np.array([[1,1,1],             # U-shape
                      [1,0,1],
                      [1,1,1]]),
            np.array([[1,1,0],             # L-shape
                      [1,0,0]])
        ]

    def seed(self, seed=None):
        """
        Seed the environment's RNGs for reproducible layouts.
        """
        np.random.seed(seed)
        random.seed(seed)
        return [seed]

    def reset(self, *, seed=None, options=None):
        """
        Reset the environment; returns obs, info
        """
        if seed is not None:
            self.seed(seed)

        self.curriculum_level = min(self.curriculum_max, self.curriculum_level + 1)
        while True:
            grid = np.zeros((self.H, self.W), dtype=int)
            allowed = self.shape_library[: self.curriculum_level + 1]
            num_shapes = np.random.randint(1, self.curriculum_level * 2 + 1)
            placed = np.zeros_like(grid)
            for _ in range(num_shapes):
                shape = random.choice(allowed)
                sh, sw = shape.shape
                i = np.random.randint(0, self.H - sh + 1)
                j = np.random.randint(0, self.W - sw + 1)
                if not np.any(placed[i:i+sh, j:j+sw] & shape):
                    placed[i:i+sh, j:j+sw] |= shape
            grid = placed

            ti = np.random.randint(0, self.H - 3 + 1)
            tj = np.random.randint(0, self.W - 3 + 1)
            full_block = [(ti+di, tj+dj) for di in range(3) for dj in range(3)]
            targets = [(i,j) for (i,j) in full_block if grid[i,j] == 0]
            if not targets:
                continue

            free_cells = list(zip(*np.where(grid == 0)))
            start = random.choice(free_cells)
            if bfs_reachable(grid, start, targets):
                break

        self.grid = grid
        self.targets = set(targets)
        self.agent_pos = start
        self.visited = set()
        self.steps = 0

        return self._get_obs(), {}

    def _get_obs(self):
        flat_grid = self.grid.flatten()
        ai, aj = self.agent_pos
        agent_vec = np.array([ai/(self.H-1), aj/(self.W-1)], dtype=np.float32)
        cover_mask = np.zeros_like(flat_grid)
        for (i,j) in self.targets:
            cover_mask[i*self.W + j] = 1
        return np.concatenate([flat_grid, agent_vec, cover_mask])

    def step(self, action):
        # Define movement vectors
        # 0 = down, 1 = up, 2 = right, 3 = left
        moves = {0: (1, 0), 1: (-1, 0), 2: (0, 1), 3: (0, -1)}
        i, j = self.agent_pos
        di, dj = moves[action]
        ni, nj = i + di, j + dj

        # Default baseline reward
        reward = 0

        # Check validity and apply penalties
        if not (0 <= ni < self.H and 0 <= nj < self.W and self.grid[ni, nj] == 0):
            # Invalid action: stay in place
            self.agent_pos = (i, j) 
        else:
            # Valid move: update position
            self.agent_pos = (ni, nj)

        # Check if on a target
        if self.agent_pos not in self.visited:
            if self.agent_pos in self.targets:
                reward = 2.0   # new target
            self.visited.add(self.agent_pos)

        # Step count
        self.steps += 1

        # Terminal bonus
        terminated = (self.visited == self.targets)
        truncated = (self.steps >= self.max_steps)
        if terminated:
            reward += 30.0

        return self._get_obs(), reward, terminated, truncated, {}

    def render(self, mode="human"):
        disp = np.full((self.H, self.W), '.', dtype=str)
        for (i,j) in self.targets:
            disp[i,j] = 'T'
        for (i,j) in zip(*np.where(self.grid == 1)):
            disp[i,j] = '#'
        ai, aj = self.agent_pos
        disp[ai, aj] = 'A'
        print("\n".join("".join(row) for row in disp))

    def close(self):
        pass

# %%
gym.register(
    id="Coverage-v0",
    entry_point="coverage_env:CoverageEnv",
    max_episode_steps=200,
)
# Out:
# /Users/pedropertusi/Desktop/reinforcement-learning/Coverage-Path-Planning/env/lib/python3.12/site-packages/gymnasium/envs/registration.py:642: UserWarning: WARN: Overriding environment Coverage-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

# instantiate a single env (you can wrap VecEnv for parallelism later)
env = CoverageEnv(seed=42)

# create the DQN model
model = DQN(
    policy="MlpPolicy",   # a simple MLP
    env=env,
    learning_starts=1000,
    buffer_size=500_000,
    learning_rate=1e-3,
    batch_size=32,
    gamma=0.99,
    verbose=1,
)

# train for 50k timesteps
model.learn(total_timesteps=500_000)

# save it
model.save("dqn_coverage")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 29053    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 9550     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.185    |
# |    n_updates        | 149      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 7149     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0449   |
# |    n_updates        | 349      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 6388     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3200     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0467   |
# |    n_updates        | 549      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 6026     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0934   |
# |    n_updates        | 749      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 5787     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4800     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000512 |
# |    n_updates        | 949      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 5629     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5600     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.09     |
# |    n_updates        | 1149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 5475     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6400     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0466   |
# |    n_updates        | 1349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 5396     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000701 |
# |    n_updates        | 1549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 5284     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0897   |
# |    n_updates        | 1749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 5234     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8800     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000656 |
# |    n_updates        | 1949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 5195     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9600     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0445   |
# |    n_updates        | 2149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 5161     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10400    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0478   |
# |    n_updates        | 2349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 5130     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11200    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000341 |
# |    n_updates        | 2549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 5107     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00113  |
# |    n_updates        | 2749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.757    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 5080     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12800    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00195  |
# |    n_updates        | 2949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 5058     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13600    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.173    |
# |    n_updates        | 3149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 5039     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 14400    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0465   |
# |    n_updates        | 3349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.711    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 5016     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15200    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0464   |
# |    n_updates        | 3549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4980     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000759 |
# |    n_updates        | 3749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4957     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16800    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00146  |
# |    n_updates        | 3949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4933     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17600    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0858   |
# |    n_updates        | 4149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.65     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4913     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18400    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.
|
# |    time_elapsed     | 14       |
# |    total_timesteps  | 60447    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0879   |
# |    n_updates        | 14861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 8.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 4279     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 61247    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0554   |
# |    n_updates        | 15061    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 8.12     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 4274     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 62047    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0326   |
# |    n_updates        | 15261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 7.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 4270     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 62847    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0352   |
# |    n_updates        | 15461    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 7.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 4266     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 63647    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0455   |
# |    n_updates        | 15661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 7.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 4262     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 64447    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00553  |
# |    n_updates        | 15861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 7.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 4258     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 65247    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0533   |
# |    n_updates        | 16061    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 7.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 4253     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 66047    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0588   |
# |    n_updates        | 16261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 7.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 4248     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 66847    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.133    |
# |    n_updates        | 16461    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 7.14     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 4245     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 67647    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00445  |
# |    n_updates        | 16661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 7.04     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 4241     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 68447    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0483   |
# |    n_updates        | 16861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 7.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 4237     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 69247    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00391  |
# |    n_updates        | 17061    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 6.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 4234     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 70047    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0596   |
# |    n_updates        | 17261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 6.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 4231     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 70847    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00558  |
# |    n_updates        | 17461    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 6.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 4228     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 71647    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0414   |
# |    n_updates        | 17661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 6.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 4225     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 72447    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00637  |
# |    n_updates        | 17861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 6.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# ...
# |    time_elapsed     | 122      |
# |    total_timesteps  | 475617   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0482   |
# |    n_updates        | 118654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 5.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2384     |
# |    fps              | 3880     |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 476417   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0542   |
# |    n_updates        | 118854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 5.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2388     |
# |    fps              | 3880     |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 477217   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0658   |
# |    n_updates        | 119054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 5.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2392     |
# |    fps              | 3880     |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 478017   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0532   |
# |    n_updates        | 119254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 5.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2396     |
# |    fps              | 3880     |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 478817   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0528   |
# |    n_updates        | 119454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 5.4      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2400     |
# |    fps              | 3880     |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 479617   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00214  |
# |    n_updates        | 119654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 5.42     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2404     |
# |    fps              | 3880     |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 480417   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0067   |
# |    n_updates        | 119854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 5.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2408     |
# |    fps              | 3880     |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 481217   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.108    |
# |    n_updates        | 120054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 5.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2412     |
# |    fps              | 3879     |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 482017   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00495  |
# |    n_updates        | 120254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 5.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2416     |
# |    fps              | 3879     |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 482817   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00568  |
# |    n_updates        | 120454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 5.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2420     |
# |    fps              | 3879     |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 483617   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0627   |
# |    n_updates        | 120654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 5.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2424     |
# |    fps              | 3879     |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 484417   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0559   |
# |    n_updates        | 120854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2428     |
# |    fps              | 3879     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 485217   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0234   |
# |    n_updates        | 121054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 5.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2432     |
# |    fps              | 3879     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 486017   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.102    |
# |    n_updates        | 121254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2436     |
# |    fps              | 3879     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 486817   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0483   |
# |    n_updates        | 121454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.86     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2440     |
# |    fps              | 3879     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 487617   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.113    |
# |    n_updates        | 121654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.86     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2444     |
# |    fps              | 3879     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 488417   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0651   |
# |    n_updates        | 121854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2448     |
# |    fps              | 3879     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 489217   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0607   |
# |    n_updates        | 122054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2452     |
# |    fps              | 3879     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 490017   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0512   |
# |    n_updates        | 122254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2456     |
# |    fps              | 3878     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 490817   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00452  |
# |    n_updates        | 122454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 5        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2460     |
# |    fps              | 3878     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 491617   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00438  |
# |    n_updates        | 122654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2464     |
# |    fps              | 3878     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 492417   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0042   |
# |    n_updates        | 122854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2468     |
# |    fps              | 3878     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 493217   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.172    |
# |    n_updates        | 123054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2472     |
# |    fps              | 3879     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 494017   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00664  |
# |    n_updates        | 123254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2476     |
# |    fps              | 3879     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 494817   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0051   |
# |    n_updates        | 123454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2480     |
# |    fps              | 3878     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 495617   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.006    |
# |    n_updates        | 123654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2484     |
# |    fps              | 3877     |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 496417   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00424  |
# |    n_updates        | 123854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2488     |
# |    fps              | 3878     |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 497217   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0521   |
# |    n_updates        | 124054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2492     |
# |    fps              | 3877     |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 498017   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00929  |
# |    n_updates        | 124254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2496     |
# |    fps              | 3878     |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 498817   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0536   |
# |    n_updates        | 124454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.46     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2500     |
# |    fps              | 3878     |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 499617   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0548   |
# |    n_updates        | 124654   |
# ----------------------------------

# %%
# load (if needed)
# model = DQN.load("dqn_coverage", env=env)

mean_reward, std_reward = evaluate_policy(
    model, 
    env, 
    n_eval_episodes=20, 
    deterministic=True,
)
print(f"Mean reward: {mean_reward:.2f} ± {std_reward:.2f}")
# Out:
# /Users/pedropertusi/Desktop/reinforcement-learning/Coverage-Path-Planning/env/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward: 0.80 ± 1.83

# %%
obs, _ = env.reset(seed=42)

for i in range(env.max_steps):
    # model.predict returns e.g. array([2], dtype=int64)
    action_arr, _ = model.predict(obs, deterministic=True)
    action = int(action_arr)       # unwrap to Python int
    print("step:", i, "action:", action)

    obs, reward, terminated, truncated, info = env.step(action)
    env.render()
    print("\n")

    if terminated or truncated:
        break
# Out:
# step: 0 action: 0
# ........
# ........
# ..TTT.A#
# ..TTT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 1 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 2 action: 3
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 3 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 4 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 5 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 6 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 7 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 8 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 9 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 10 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 11 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 12 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 13 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 14 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 15 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 16 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 17 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 18 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 19 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 20 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 21 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 22 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 23 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 24 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 25 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 26 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 27 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 28 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 29 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 30 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 31 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 32 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 33 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 34 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 35 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 36 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 37 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 38 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 39 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 40 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 41 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 42 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 43 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 44 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 45 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 46 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 47 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 48 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 49 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 50 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 51 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 52 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 53 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 54 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 55 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 56 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 57 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 58 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 59 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 60 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 61 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 62 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 63 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 64 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 65 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 66 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 67 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 68 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 69 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 70 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 71 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 72 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 73 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 74 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 75 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 76 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 77 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 78 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 79 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 80 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 81 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 82 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 83 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 84 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 85 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 86 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 87 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 88 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 89 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 90 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 91 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 92 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 93 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 94 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 95 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 96 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 97 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 98 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 99 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 100 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 101 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 102 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 103 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 104 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 105 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 106 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 107 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 108 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 109 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 110 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 111 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 112 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 113 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 114 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 115 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 116 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 117 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 118 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 119 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 120 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 121 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 122 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 123 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 124 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 125 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 126 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 127 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 128 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 129 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 130 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 131 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 132 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 133 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 134 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 135 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 136 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 137 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 138 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 139 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 140 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 141 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 142 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 143 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 144 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 145 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 146 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 147 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 148 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 149 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 150 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 151 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 152 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 153 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 154 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 155 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 156 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 157 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 158 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 159 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 160 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 161 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 162 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 163 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 164 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 165 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 166 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 167 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 168 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 169 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 170 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 171 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 172 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 173 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 174 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 175 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 176 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 177 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 178 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 179 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 180 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 181 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 182 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 183 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 184 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 185 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 186 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 187 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 188 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 189 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 190 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 191 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 192 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 193 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 194 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 195 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 196 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 197 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 198 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 199 action: 0
# ........
# ........
# ..TTT..#
# ..TTTA..
# ..TT###.
# ....##..
# .###....
# ........
