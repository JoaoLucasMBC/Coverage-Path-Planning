# %%
import numpy as np
import gymnasium as gym
import random
from gymnasium import spaces
from collections import deque

# %%
def bfs_reachable(grid, start, targets):
    """
    Check if all target cells are reachable from start on grid (0=free, 1=obstacle).
    """
    H, W = grid.shape
    visited = np.zeros_like(grid, dtype=bool)
    queue = deque([start])
    visited[start] = True
    reached = set()
    while queue:
        i, j = queue.popleft()
        if (i, j) in targets:
            reached.add((i, j))
            if reached == set(targets):
                return True
        for di, dj in ((1,0),(-1,0),(0,1),(0,-1)):
            ni, nj = i+di, j+dj
            if 0 <= ni < H and 0 <= nj < W and not visited[ni, nj] and grid[ni, nj] == 0:
                visited[ni, nj] = True
                queue.append((ni, nj))
    return False

# %%
class CoverageEnv(gym.Env):
    metadata = {"render.modes": ["human"]}

    def __init__(self, curriculum_max=3, max_steps=200, seed=None):
        super().__init__()
        self.H, self.W = 8, 8
        self.curriculum_level = 0
        self.curriculum_max = curriculum_max
        self.max_steps = max_steps

        # seeding for reproducibility
        self.seed(seed)

        # Action: down, up, right, left
        self.action_space = spaces.Discrete(4)
        self.observation_space = spaces.Box(0.0, 1.0, shape=(5, self.H, self.W), dtype=np.float32)

        # Define a fixed shape library
        self.shape_library = [
            np.array([[1]]),                # single cell
            np.ones((1,3), dtype=int),     # horizontal bar
            np.ones((2,2), dtype=int),     # 2x2 block
            np.array([[1,1,1],             # U-shape
                      [1,0,1],
                      [1,1,1]]),
            np.array([[1,1,0],             # L-shape
                      [1,0,0]])
        ]

    def seed(self, seed=None):
        """
        Seed the environment's RNGs for reproducible layouts.
        """
        np.random.seed(seed)
        random.seed(seed)
        return [seed]

    def reset(self, *, seed=None, options=None):
        """
        Reset the environment; returns obs (shape C×H×W), info
        Channels:
         0 = free space
         1 = obstacles
         2 = agent location
         3 = target area
         4 = visited mask (all zeros at reset)
        """
        if seed is not None:
            self.seed(42)
        else:
            self.seed(42)

        self.curriculum_level = min(self.curriculum_max, self.curriculum_level + 1)

        while True:
            grid = np.zeros((self.H, self.W), dtype=int)
            allowed = self.shape_library[: self.curriculum_level + 1]
            num_shapes = np.random.randint(1, self.curriculum_level * 2 + 1)
            placed = np.zeros_like(grid)
            for _ in range(num_shapes):
                shape = random.choice(allowed)
                sh, sw = shape.shape
                i = np.random.randint(0, self.H - sh + 1)
                j = np.random.randint(0, self.W - sw + 1)
                if not np.any(placed[i:i+sh, j:j+sw] & shape):
                    placed[i:i+sh, j:j+sw] |= shape
            grid = placed

            ti = np.random.randint(0, self.H - 3 + 1)
            tj = np.random.randint(0, self.W - 3 + 1)
            full_block = [(ti+di, tj+dj) for di in range(3) for dj in range(3)]
            targets = [(i,j) for (i,j) in full_block if grid[i,j] == 0]
            if not targets:
                continue

            free_cells = list(zip(*np.where(grid == 0)))
            start = random.choice(free_cells)
            if bfs_reachable(grid, start, targets):
                break

        self.grid = grid
        self.targets = set(targets)
        self.agent_pos = start
        self.visited = { start }
        self.steps = 0

        return self._get_obs(), {}

    def _get_obs(self):
        C = 5
        state = np.zeros((C, self.H, self.W), dtype=np.float32)

        # channel 0: free space (grid==0)
        state[0, :, :] = (self.grid == 0).astype(np.float32)
        # channel 1: obstacles (grid!=0)
        state[1, :, :] = (self.grid != 0).astype(np.float32)
        # channel 2: agent location
        i, j = self.agent_pos
        state[2, i, j] = 1.0
        # channel 3: target area
        for (ti, tj) in self.targets:
            state[3, ti, tj] = 1.0
        for vi, vj in self.visited:
            state[4, vi, vj] = 1.0
        
        return state

    def step(self, action):
        # Define movement vectors
        # 0 = down, 1 = up, 2 = right, 3 = left
        moves = {0: (1, 0), 1: (-1, 0), 2: (0, 1), 3: (0, -1)}
        i, j = self.agent_pos
        di, dj = moves[action]
        ni, nj = i + di, j + dj

        # Default baseline reward
        reward = 0

        # Check validity and apply penalties
        if not (0 <= ni < self.H and 0 <= nj < self.W and self.grid[ni, nj] == 0):
            # Invalid action: stay in place
            self.agent_pos = (i, j) 
        else:
            # Valid move: update position
            self.agent_pos = (ni, nj)

        # Check if on a target
        if self.agent_pos not in self.visited:
            if self.agent_pos in self.targets:
                reward = 2.0   # new target
            self.visited.add(self.agent_pos)
        else:
            reward = -1

        # Step count
        self.steps += 1

        # Terminal bonus
        terminated = True
        for (i,j) in self.targets:
            if (i,j) not in self.visited:
                terminated = False
                break
            
        truncated = (self.steps >= self.max_steps)
        if terminated:
            reward += 30.0

        return self._get_obs(), reward, terminated, truncated, {}

    def render(self, mode="human"):
        disp = np.full((self.H, self.W), '.', dtype=str)
        for (i,j) in self.targets:
            disp[i,j] = 'T'
        for (i,j) in zip(*np.where(self.grid == 1)):
            disp[i,j] = '#'
        ai, aj = self.agent_pos
        disp[ai, aj] = 'A'
        print("\n".join("".join(row) for row in disp))

    def close(self):
        pass

# %%
gym.register(
    id="Coverage-v0",
    entry_point="coverage_env:CoverageEnv",
    max_episode_steps=200,
)

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

# instantiate a single env (you can wrap VecEnv for parallelism later)
env = CoverageEnv(seed=42)

# create the DQN model
model = DQN(
    policy="MlpPolicy",   # a simple MLP
    env=env,
    buffer_size=100000,
    learning_rate=1e-4,
    batch_size=32,
    gamma=0.99,
    verbose=1,
)

# train for 50k timesteps
model.learn(total_timesteps=500_000)

# save it
model.save("dqn_coverage")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -153     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4164     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.107    |
# |    n_updates        | 174      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | -119     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4351     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1425     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.139    |
# |    n_updates        | 331      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4470     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2035     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.224    |
# |    n_updates        | 483      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | -95.9    |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4503     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2555     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.325    |
# |    n_updates        | 613      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 162      |
# |    ep_rew_mean      | -98.2    |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4456     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3246     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.09     |
# |    n_updates        | 786      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | -95.8    |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4487     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3831     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.12     |
# |    n_updates        | 932      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -87.6    |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 4504     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4300     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.201    |
# |    n_updates        | 1049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -90.5    |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4519     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4966     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.257    |
# |    n_updates        | 1216     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | -91.9    |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4491     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5625     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.183    |
# |    n_updates        | 1381     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -91.3    |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 4482     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6205     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.108    |
# |    n_updates        | 1526     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | -87.6    |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 4490     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6680     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 1644     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -85.3    |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4495     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7254     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.175    |
# |    n_updates        | 1788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 150      |
# |    ep_rew_mean      | -83.6    |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4498     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7782     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 1920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 147      |
# |    ep_rew_mean      | -80.7    |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4497     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8233     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0649   |
# |    n_updates        | 2033     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | -82.3    |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4504     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8926     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14     |
# |    n_updates        | 2206     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 150      |
# |    ep_rew_mean      | -83.7    |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4509     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9582     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.34     |
# |    n_updates        | 2370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -85.2    |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 4456     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10279    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.128    |
# |    n_updates        | 2544     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -84.8    |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 4454     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10874    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.247    |
# |    n_updates        | 2693     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -84.8    |
# |    exploration_rate | 0.782    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4449     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11477    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.115    |
# |    n_updates        | 2844     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 150      |
# |    ep_rew_mean      | -84.2    |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4448     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12010    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0651   |
# |    n_updates        | 2977     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -86      |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4452     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12724    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.228    |
# |    n_updates        | 3155     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | -86.7    |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4455     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 13380    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0611   |
# |    n_updates        | 3319     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | -87.6    |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4455     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 14068    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 3491     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -88.8    |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 4450     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 14788    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.164    |
# |    n_updates        | 3671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -89.4    |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4443     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15435    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.201    |
# |    n_updates        | 3833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -89.5    |
# |    exploration_rate | 0.692    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4445     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16235    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.11     |
# |    n_updates        | 4033     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -90.3    |
# |    exploration_rate | 0.679    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4442     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16894    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.122    |
# |    n_updates        | 4198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -90.3    |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4440     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17517    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.14     |
# |    n_updates        | 4354     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -90.5    |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 4439     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 17978    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.1      |
# |    n_updates        | 4469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | -88.4    |
# |    exploration_rate | 0.649    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 4436     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18459    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13     |
# |    n_updates        | 4589     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | -89.7    |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4437     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19127    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.192    |
# |    n_updates        | 4756     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | -89.7    |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4437     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19531    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.07     |
# |    n_updates        | 4857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -88.1    |
# |    exploration_rate | 0.618    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4431     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 20088    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.34     |
# |    n_updates        | 4996     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -88.1    |
# |    exploration_rate | 0.606    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 4427     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 20745    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.126    |
# |    n_updates        | 5161     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -87.2    |
# |    exploration_rate | 0.595    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 4424     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 21292    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0602   |
# |    n_updates        | 5297     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | -88.5    |
# |    exploration_rate | 0.585    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 4420     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 21867    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0951   |
# |    n_updates        | 5441     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -88.6    |
# |    exploration_rate | 0.575    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 4418     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 22390    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.175    |
# |    n_updates        | 5572     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | -91.1    |
# |    exploration_rate | 0.561    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 4410     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 23119    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0821   |
# |    n_updates        | 5754     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -93.4    |
# |    exploration_rate | 0.549    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 4400     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 23738    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.127    |
# |    n_updates        | 5909     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | -95.4    |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 4392     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 24538    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 6109     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | -96.3    |
# |    exploration_rate | 0.52     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 4325     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 25267    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0785   |
# |    n_updates        | 6291     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -98.2    |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 4315     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 26067    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.114    |
# |    n_updates        | 6491     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | -97.3    |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 4311     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 26527    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.272    |
# |    n_updates        | 6606     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -95.8    |
# |    exploration_rate | 0.487    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 4310     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 26977    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0401   |
# |    n_updates        | 6719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -98.8    |
# |    exploration_rate | 0.472    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 4307     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 27777    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 6919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -99.5    |
# |    exploration_rate | 0.457    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 4304     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 28574    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0725   |
# |    n_updates        | 7118     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -101     |
# |    exploration_rate | 0.443    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 4300     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 29296    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0763   |
# |    n_updates        | 7298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | -98.8    |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 4297     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 29777    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0521   |
# |    n_updates        | 7419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -96.6    |
# |    exploration_rate | 0.424    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 4293     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 30323    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.21     |
# |    n_updates        | 7555     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -94.5    |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 4289     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 30792    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 7672     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | -89.3    |
# |    exploration_rate | 0.408    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 4286     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 31143    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.168    |
# |    n_updates        | 7760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | -85.8    |
# |    exploration_rate | 0.402    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 4283     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 31494    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0535   |
# |    n_updates        | 7848     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 143      |
# |    ep_rew_mean      | -82.4    |
# |    exploration_rate | 0.396    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 4281     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 31792    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.142    |
# |    n_updates        | 7922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | -82.6    |
# |    exploration_rate | 0.386    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 4278     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 32333    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.257    |
# |    n_updates        | 8058     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | -81.5    |
# |    exploration_rate | 0.379    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 4275     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 32692    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.185    |
# |    n_updates        | 8147     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 139      |
# |    ep_rew_mean      | -77.6    |
# |    exploration_rate | 0.373    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 4271     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 33010    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.214    |
# |    n_updates        | 8227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | -80.5    |
# |    exploration_rate | 0.36     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 4266     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 33662    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0406   |
# |    n_updates        | 8390     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | -79.7    |
# |    exploration_rate | 0.352    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 4262     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 34130    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.113    |
# |    n_updates        | 8507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | -77.2    |
# |    exploration_rate | 0.343    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 4259     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 34566    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.118    |
# |    n_updates        | 8616     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | -79.3    |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 4254     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 35247    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 8786     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -76.4    |
# |    exploration_rate | 0.325    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 4251     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 35535    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 8858     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -76.3    |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 4248     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 36014    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.232    |
# |    n_updates        | 8978     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -74.6    |
# |    exploration_rate | 0.305    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 4243     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 36597    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.23     |
# |    n_updates        | 9124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 132      |
# |    ep_rew_mean      | -71.9    |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 4240     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 36965    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.172    |
# |    n_updates        | 9216     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | -67.8    |
# |    exploration_rate | 0.289    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 4237     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 37442    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.287    |
# |    n_updates        | 9335     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 124      |
# |    ep_rew_mean      | -62.9    |
# |    exploration_rate | 0.283    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 4234     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 37711    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.198    |
# |    n_updates        | 9402     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | -57.9    |
# |    exploration_rate | 0.276    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 4231     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 38089    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.201    |
# |    n_updates        | 9497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 122      |
# |    ep_rew_mean      | -59.7    |
# |    exploration_rate | 0.264    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 4226     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 38712    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.116    |
# |    n_updates        | 9652     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | -58.7    |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 4222     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 39076    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.206    |
# |    n_updates        | 9743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -54.1    |
# |    exploration_rate | 0.25     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 4208     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 39496    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0865   |
# |    n_updates        | 9848     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -51.7    |
# |    exploration_rate | 0.239    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 4201     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 40048    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.284    |
# |    n_updates        | 9986     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | -47.5    |
# |    exploration_rate | 0.232    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 4198     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 40395    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 10073    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | -46.8    |
# |    exploration_rate | 0.224    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 4194     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 40858    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.137    |
# |    n_updates        | 10189    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | -49.2    |
# |    exploration_rate | 0.211    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 4189     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 41535    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.171    |
# |    n_updates        | 10358    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | -49.7    |
# |    exploration_rate | 0.202    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 4185     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 42003    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 10475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -52.7    |
# |    exploration_rate | 0.189    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 4180     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 42691    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0531   |
# |    n_updates        | 10647    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -55.3    |
# |    exploration_rate | 0.178    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 4175     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 43249    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.145    |
# |    n_updates        | 10787    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | -59.2    |
# |    exploration_rate | 0.166    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 4170     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 43883    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0944   |
# |    n_updates        | 10945    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | -57.7    |
# |    exploration_rate | 0.159    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 4167     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 44284    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.102    |
# |    n_updates        | 11045    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | -57.7    |
# |    exploration_rate | 0.152    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 4164     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 44643    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 11135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | -58.4    |
# |    exploration_rate | 0.145    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 4161     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 45014    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.157    |
# |    n_updates        | 11228    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -53.4    |
# |    exploration_rate | 0.141    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 4159     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 45186    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.106    |
# |    n_updates        | 11271    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -51.8    |
# |    exploration_rate | 0.136    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 4156     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 45474    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0904   |
# |    n_updates        | 11343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | -50      |
# |    exploration_rate | 0.131    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 4154     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 45719    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.165    |
# |    n_updates        | 11404    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -44.4    |
# |    exploration_rate | 0.129    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 4152     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 45860    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.153    |
# |    n_updates        | 11439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -46      |
# |    exploration_rate | 0.12     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 4148     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 46296    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.139    |
# |    n_updates        | 11548    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -47.1    |
# |    exploration_rate | 0.109    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 4144     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 46881    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.153    |
# |    n_updates        | 11695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -43.4    |
# |    exploration_rate | 0.105    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 4142     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 47090    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.202    |
# |    n_updates        | 11747    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -44.9    |
# |    exploration_rate | 0.096    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 4137     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 47581    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0935   |
# |    n_updates        | 11870    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -44.2    |
# |    exploration_rate | 0.0889   |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 4134     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 47952    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14     |
# |    n_updates        | 11962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -44.4    |
# |    exploration_rate | 0.0838   |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 4131     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 48222    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.157    |
# |    n_updates        | 12030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# ...
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497015   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000926 |
# |    n_updates        | 124228   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 39       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15976    |
# |    fps              | 3332     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497103   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.708    |
# |    n_updates        | 124250   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 39.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15980    |
# |    fps              | 3332     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497153   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.744    |
# |    n_updates        | 124263   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 40       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15984    |
# |    fps              | 3332     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497201   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00365  |
# |    n_updates        | 124275   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 40       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15988    |
# |    fps              | 3332     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497251   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00216  |
# |    n_updates        | 124287   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 41.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15992    |
# |    fps              | 3332     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497299   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00111  |
# |    n_updates        | 124299   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 43.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15996    |
# |    fps              | 3332     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497347   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000965 |
# |    n_updates        | 124311   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 44.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16000    |
# |    fps              | 3332     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497395   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000871 |
# |    n_updates        | 124323   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 44.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16004    |
# |    fps              | 3331     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497441   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000944 |
# |    n_updates        | 124335   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 44.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16008    |
# |    fps              | 3331     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497491   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000841 |
# |    n_updates        | 124347   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 44.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16012    |
# |    fps              | 3331     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497539   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000719 |
# |    n_updates        | 124359   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 44.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16016    |
# |    fps              | 3331     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497587   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000708 |
# |    n_updates        | 124371   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 44.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16020    |
# |    fps              | 3331     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497635   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000695 |
# |    n_updates        | 124383   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 43.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16024    |
# |    fps              | 3330     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497793   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 124423   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 43.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16028    |
# |    fps              | 3330     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497843   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00987  |
# |    n_updates        | 124435   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 43.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16032    |
# |    fps              | 3330     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497889   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00743  |
# |    n_updates        | 124447   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 43.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16036    |
# |    fps              | 3330     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497939   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00213  |
# |    n_updates        | 124459   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 43.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16040    |
# |    fps              | 3330     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 497987   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00182  |
# |    n_updates        | 124471   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 43.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16044    |
# |    fps              | 3329     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 498035   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00144  |
# |    n_updates        | 124483   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 43.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16048    |
# |    fps              | 3329     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 498083   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000783 |
# |    n_updates        | 124495   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 43.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16052    |
# |    fps              | 3329     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 498131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000986 |
# |    n_updates        | 124507   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 43.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16056    |
# |    fps              | 3329     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 498179   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000698 |
# |    n_updates        | 124519   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 43.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16060    |
# |    fps              | 3329     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 498225   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000597 |
# |    n_updates        | 124531   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 41.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16064    |
# |    fps              | 3329     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 498438   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 124584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 41.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16068    |
# |    fps              | 3329     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 498484   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0111   |
# |    n_updates        | 124595   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 41.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16072    |
# |    fps              | 3329     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 498532   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00382  |
# |    n_updates        | 124607   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 35.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16076    |
# |    fps              | 3329     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 499144   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.527    |
# |    n_updates        | 124760   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 35.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16080    |
# |    fps              | 3329     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 499192   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 124772   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 30.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16084    |
# |    fps              | 3329     |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 499616   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 124878   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 30.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16088    |
# |    fps              | 3329     |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 499662   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 124890   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26       |
# |    ep_rew_mean      | 28.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16092    |
# |    fps              | 3329     |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 499900   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 124949   |
# ----------------------------------

# %%
# load (if needed)
# model = DQN.load("dqn_coverage", env=env)

mean_reward, std_reward = evaluate_policy(
    model, 
    env, 
    n_eval_episodes=20, 
    deterministic=True,
)
print(f"Mean reward: {mean_reward:.2f} ± {std_reward:.2f}")
# Out:
# Mean reward: 46.00 ± 0.00
# /Users/pedropertusi/Desktop/reinforcement-learning/Coverage-Path-Planning/env/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
obs, _ = env.reset(seed=42)

for i in range(env.max_steps):
    # model.predict returns e.g. array([2], dtype=int64)
    action_arr, _ = model.predict(obs, deterministic=True)
    action = int(action_arr)       # unwrap to Python int
    print("step:", i, "action:", action)

    obs, reward, terminated, truncated, info = env.step(action)
    env.render()
    print("\n")

    if terminated or truncated:
        break
# Out:
# step: 0 action: 3
# ........
# .....A..
# ..TTT..#
# ..TTT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 1 action: 0
# ........
# ........
# ..TTTA.#
# ..TTT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 2 action: 3
# ........
# ........
# ..TTA..#
# ..TTT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 3 action: 3
# ........
# ........
# ..TAT..#
# ..TTT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 4 action: 3
# ........
# ........
# ..ATT..#
# ..TTT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 5 action: 0
# ........
# ........
# ..TTT..#
# ..ATT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 6 action: 0
# ........
# ........
# ..TTT..#
# ..TTT...
# ..AT###.
# ....##..
# .###....
# ........
#
#
# step: 7 action: 2
# ........
# ........
# ..TTT..#
# ..TTT...
# ..TA###.
# ....##..
# .###....
# ........
#
#
# step: 8 action: 1
# ........
# ........
# ..TTT..#
# ..TAT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 9 action: 2
# ........
# ........
# ..TTT..#
# ..TTA...
# ..TT###.
# ....##..
# .###....
# ........
