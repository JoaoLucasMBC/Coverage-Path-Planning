# %%
import numpy as np
import gymnasium as gym
import random
from gymnasium import spaces
from collections import deque

# %%
def bfs_reachable(grid, start, targets):
    """
    Check if all target cells are reachable from start on grid (0=free, 1=obstacle).
    """
    H, W = grid.shape
    visited = np.zeros_like(grid, dtype=bool)
    queue = deque([start])
    visited[start] = True
    reached = set()
    while queue:
        i, j = queue.popleft()
        if (i, j) in targets:
            reached.add((i, j))
            if reached == set(targets):
                return True
        for di, dj in ((1,0),(-1,0),(0,1),(0,-1)):
            ni, nj = i+di, j+dj
            if 0 <= ni < H and 0 <= nj < W and not visited[ni, nj] and grid[ni, nj] == 0:
                visited[ni, nj] = True
                queue.append((ni, nj))
    return False

# %%
class CoverageEnv(gym.Env):
    metadata = {"render.modes": ["human"]}

    def __init__(self, curriculum_max=3, max_steps=200, seed=None):
        super().__init__()
        self.H, self.W = 8, 8
        self.curriculum_level = 0
        self.curriculum_max = curriculum_max
        self.max_steps = max_steps

        # seeding for reproducibility
        self.seed(seed)

        # Action: down, up, right, left
        self.action_space = spaces.Discrete(4)
        self.observation_space = spaces.Box(0.0, 1.0, shape=(5, self.H, self.W), dtype=np.float32)

        # Define a fixed shape library
        self.shape_library = [
            np.array([[1]]),                # single cell
            np.ones((1,3), dtype=int),     # horizontal bar
            np.ones((2,2), dtype=int),     # 2x2 block
            np.array([[1,1,1],             # U-shape
                      [1,0,1],
                      [1,1,1]]),
            np.array([[1,1,0],             # L-shape
                      [1,0,0]])
        ]

    def seed(self, seed=None):
        """
        Seed the environment's RNGs for reproducible layouts.
        """
        np.random.seed(seed)
        random.seed(seed)
        return [seed]

    def reset(self, *, seed=None, options=None):
        """
        Reset the environment; returns obs (shape C×H×W), info
        Channels:
         0 = free space
         1 = obstacles
         2 = agent location
         3 = target area
         4 = visited mask (all zeros at reset)
        """
        if seed is not None:
            self.seed(42)
        else:
            self.seed(42)

        self.curriculum_level = min(self.curriculum_max, self.curriculum_level + 1)

        while True:
            grid = np.zeros((self.H, self.W), dtype=int)
            allowed = self.shape_library[: self.curriculum_level + 1]
            num_shapes = np.random.randint(1, self.curriculum_level * 2 + 1)
            placed = np.zeros_like(grid)
            for _ in range(num_shapes):
                shape = random.choice(allowed)
                sh, sw = shape.shape
                i = np.random.randint(0, self.H - sh + 1)
                j = np.random.randint(0, self.W - sw + 1)
                if not np.any(placed[i:i+sh, j:j+sw] & shape):
                    placed[i:i+sh, j:j+sw] |= shape
            grid = placed

            ti = np.random.randint(0, self.H - 3 + 1)
            tj = np.random.randint(0, self.W - 3 + 1)
            full_block = [(ti+di, tj+dj) for di in range(3) for dj in range(3)]
            targets = [(i,j) for (i,j) in full_block if grid[i,j] == 0]
            if not targets:
                continue

            free_cells = list(zip(*np.where(grid == 0)))
            start = random.choice(free_cells)
            if bfs_reachable(grid, start, targets):
                break

        self.grid = grid
        self.targets = set(targets)
        self.agent_pos = start
        self.visited = { start }
        self.steps = 0

        return self._get_obs(), {}

    def _get_obs(self):
        C = 5
        state = np.zeros((C, self.H, self.W), dtype=np.float32)

        # channel 0: free space (grid==0)
        state[0, :, :] = (self.grid == 0).astype(np.float32)
        # channel 1: obstacles (grid!=0)
        state[1, :, :] = (self.grid != 0).astype(np.float32)
        # channel 2: agent location
        i, j = self.agent_pos
        state[2, i, j] = 1.0
        # channel 3: target area
        for (ti, tj) in self.targets:
            state[3, ti, tj] = 1.0
        for vi, vj in self.visited:
            state[4, vi, vj] = 1.0
        
        return state

    def step(self, action):
        # Define movement vectors
        # 0 = down, 1 = up, 2 = right, 3 = left
        moves = {0: (1, 0), 1: (-1, 0), 2: (0, 1), 3: (0, -1)}
        i, j = self.agent_pos
        di, dj = moves[action]
        ni, nj = i + di, j + dj

        # Default baseline reward
        reward = 0

        # Check validity and apply penalties
        if not (0 <= ni < self.H and 0 <= nj < self.W and self.grid[ni, nj] == 0):
            # Invalid action: stay in place
            self.agent_pos = (i, j) 
        else:
            # Valid move: update position
            self.agent_pos = (ni, nj)

        # Check if on a target
        if self.agent_pos not in self.visited:
            if self.agent_pos in self.targets:
                reward = 2.0   # new target
            self.visited.add(self.agent_pos)
        else:
            reward = -1

        # Step count
        self.steps += 1

        # Terminal bonus
        terminated = True
        for (i,j) in self.targets:
            if (i,j) not in self.visited:
                terminated = False
                break
            
        truncated = (self.steps >= self.max_steps)
        if terminated:
            reward += 30.0

        return self._get_obs(), reward, terminated, truncated, {}

    def render(self, mode="human"):
        disp = np.full((self.H, self.W), '.', dtype=str)
        for (i,j) in self.targets:
            disp[i,j] = 'T'
        for (i,j) in zip(*np.where(self.grid == 1)):
            disp[i,j] = '#'
        ai, aj = self.agent_pos
        disp[ai, aj] = 'A'
        print("\n".join("".join(row) for row in disp))

    def close(self):
        pass

# %%
gym.register(
    id="Coverage-v0",
    entry_point="coverage_env:CoverageEnv",
    max_episode_steps=200,
)

# %%
import torch as th
import torch.nn as nn
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

class SmallCNN(BaseFeaturesExtractor):
    def __init__(self, observation_space, features_dim=64):
        super().__init__(observation_space, features_dim)
        n_channels, H, W = observation_space.shape

        # A tiny two‐layer CNN
        self.cnn = nn.Sequential(
            nn.Conv2d(n_channels, 16, kernel_size=3, stride=1),  # -> (16, H-2, W-2)
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=1),          # -> (32, H-4, W-4)
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with th.no_grad():
            sample = th.as_tensor(observation_space.sample()[None]).float()
            n_flatten = self.cnn(sample).shape[1]

        # Final linear layer to get exactly features_dim outputs
        self.linear = nn.Sequential(
            nn.Linear(n_flatten, features_dim),
            nn.ReLU(),
        )

    def forward(self, observations: th.Tensor) -> th.Tensor:
        return self.linear(self.cnn(observations))

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

# instantiate a single env (you can wrap VecEnv for parallelism later)
env = CoverageEnv(seed=42)

# create the DQN model
model = DQN(
    policy="CnnPolicy",
    env=env,
    learning_starts=1000,
    buffer_size=500_000,
    learning_rate=1e-3,
    batch_size=32,
    gamma=0.99,
    policy_kwargs=dict(
        features_extractor_class=SmallCNN,
        features_extractor_kwargs=dict(features_dim=64),
        normalize_images=False,    # since you already output float32 [0,1]
    ),
    verbose=1,
)

# train for 50k timesteps
model.learn(total_timesteps=100_000)

# save it
model.save("dqn_coverage")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | -68.8    |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 10090    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 513      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | -79.8    |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 7228     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1105     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.096    |
# |    n_updates        | 26       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 150      |
# |    ep_rew_mean      | -95      |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 3063     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1795     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.13     |
# |    n_updates        | 198      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | -98.4    |
# |    exploration_rate | 0.769    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2364     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2429     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.192    |
# |    n_updates        | 357      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | -109     |
# |    exploration_rate | 0.694    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1991     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3226     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.101    |
# |    n_updates        | 556      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | -112     |
# |    exploration_rate | 0.622    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1869     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3974     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.235    |
# |    n_updates        | 743      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | -115     |
# |    exploration_rate | 0.55     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1782     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4732     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.126    |
# |    n_updates        | 932      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.474    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1704     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5532     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0396   |
# |    n_updates        | 1132     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | -124     |
# |    exploration_rate | 0.398    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1635     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6332     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.159    |
# |    n_updates        | 1332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.347    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1592     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6873     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0352   |
# |    n_updates        | 1468     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -119     |
# |    exploration_rate | 0.287    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1552     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7510     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.974    |
# |    n_updates        | 1627     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | -123     |
# |    exploration_rate | 0.211    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1492     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8310     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0419   |
# |    n_updates        | 1827     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | -126     |
# |    exploration_rate | 0.135    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1446     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9110     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0363   |
# |    n_updates        | 2027     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | -128     |
# |    exploration_rate | 0.0586   |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1402     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 9910     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0384   |
# |    n_updates        | 2227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | -128     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1368     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 10595    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0689   |
# |    n_updates        | 2398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | -124     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1337     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 11056    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0933   |
# |    n_updates        | 2513     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | -126     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1306     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 11856    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0485   |
# |    n_updates        | 2713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | -128     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1279     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 12656    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0322   |
# |    n_updates        | 2913     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | -125     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1273     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 13124    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0296   |
# |    n_updates        | 3030     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 165      |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1271     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 13199    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0134   |
# |    n_updates        | 3049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1263     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 13999    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0257   |
# |    n_updates        | 3249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 164      |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1257     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 14460    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0234   |
# |    n_updates        | 3364     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1229     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 15260    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0305   |
# |    n_updates        | 3564     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | -119     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1210     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 16060    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00939  |
# |    n_updates        | 3764     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1201     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 16672    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0335   |
# |    n_updates        | 3917     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | -122     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1197     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 17472    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0358   |
# |    n_updates        | 4117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | -124     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1190     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 18272    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0507   |
# |    n_updates        | 4317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | -122     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1186     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 18797    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0137   |
# |    n_updates        | 4449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 168      |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1182     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 19229    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0259   |
# |    n_updates        | 4557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1180     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 19841    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0375   |
# |    n_updates        | 4710     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1176     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 20554    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.078    |
# |    n_updates        | 4888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | -115     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1171     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 20987    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.126    |
# |    n_updates        | 4996     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | -115     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1165     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 21787    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0762   |
# |    n_updates        | 5196     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1162     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 22091    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.059    |
# |    n_updates        | 5272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -111     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1157     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 22746    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0198   |
# |    n_updates        | 5436     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -111     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1153     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 23358    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0892   |
# |    n_updates        | 5589     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1150     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 23970    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0293   |
# |    n_updates        | 5742     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | -105     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1150     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 24422    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0556   |
# |    n_updates        | 5855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | -96.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1150     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 24470    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0164   |
# |    n_updates        | 5867     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | -96.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1150     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 25186    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0599   |
# |    n_updates        | 6046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | -93      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1149     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 25294    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0227   |
# |    n_updates        | 6073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -84.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1149     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 25342    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.005    |
# |    n_updates        | 6085     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 127      |
# |    ep_rew_mean      | -76.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1149     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 25390    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00169  |
# |    n_updates        | 6097     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | -72.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1148     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 25438    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000942 |
# |    n_updates        | 6109     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | -71.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1147     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 25486    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000475 |
# |    n_updates        | 6121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -63.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1147     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 25534    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000271 |
# |    n_updates        | 6133     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | -59.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1147     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 25582    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000236 |
# |    n_updates        | 6145     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -53.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1145     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 25818    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00818  |
# |    n_updates        | 6204     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.1     |
# |    ep_rew_mean      | -45.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1145     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 25866    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00377  |
# |    n_updates        | 6216     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -39.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1144     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 25914    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00135  |
# |    n_updates        | 6228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.9     |
# |    ep_rew_mean      | -31.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1143     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 25962    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000942 |
# |    n_updates        | 6240     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.4     |
# |    ep_rew_mean      | -24      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1143     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 26010    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000414 |
# |    n_updates        | 6252     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.6     |
# |    ep_rew_mean      | -19.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1143     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 26058    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00021  |
# |    n_updates        | 6264     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.8     |
# |    ep_rew_mean      | -15.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1142     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 26106    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000248 |
# |    n_updates        | 6276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.1     |
# |    ep_rew_mean      | -9.18    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1142     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 26154    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000186 |
# |    n_updates        | 6288     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.5     |
# |    ep_rew_mean      | -2.45    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1142     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 26202    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000124 |
# |    n_updates        | 6300     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.6     |
# |    ep_rew_mean      | 1.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1142     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 26250    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 9.23e-05 |
# |    n_updates        | 6312     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.1     |
# |    ep_rew_mean      | 9.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1141     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26298    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.7e-05  |
# |    n_updates        | 6324     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.5     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1141     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26346    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.42e-05 |
# |    n_updates        | 6336     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.5     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1141     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26396    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.57e-05 |
# |    n_updates        | 6348     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.9     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1140     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26443    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00108  |
# |    n_updates        | 6360     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.2     |
# |    ep_rew_mean      | 30.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1140     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26491    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000311 |
# |    n_updates        | 6372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 34.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1140     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26539    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000141 |
# |    n_updates        | 6384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 34.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1139     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26587    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000247 |
# |    n_updates        | 6396     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 41.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1139     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26635    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000131 |
# |    n_updates        | 6408     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 42       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1139     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26683    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.14e-05 |
# |    n_updates        | 6420     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 42       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1138     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26731    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.84e-05 |
# |    n_updates        | 6432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 42       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1138     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26779    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.16e-05 |
# |    n_updates        | 6444     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 42       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1138     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26827    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.7e-05  |
# |    n_updates        | 6456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 42       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1137     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26875    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.22e-05 |
# |    n_updates        | 6468     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 42       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1137     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26923    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.9e-05  |
# |    n_updates        | 6480     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 42       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1136     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 26971    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.61e-05 |
# |    n_updates        | 6492     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 44       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1135     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 27019    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000122 |
# |    n_updates        | 6504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 44       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1135     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 27068    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000159 |
# |    n_updates        | 6516     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1134     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 27123    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000979 |
# |    n_updates        | 6530     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1134     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 27177    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000571 |
# |    n_updates        | 6544     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1133     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 27230    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00023  |
# |    n_updates        | 6557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1132     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 27278    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000103 |
# |    n_updates        | 6569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1132     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 27326    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.64e-05 |
# |    n_updates        | 6581     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1131     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 27374    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.21e-05 |
# |    n_updates        | 6593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1131     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 27422    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.37e-05 |
# |    n_updates        | 6605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1130     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 27470    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.72e-05 |
# |    n_updates        | 6617     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 37.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1125     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 28082    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.141    |
# |    n_updates        | 6770     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 33.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1125     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 28508    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0373   |
# |    n_updates        | 6876     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 31.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1122     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 28763    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0154   |
# |    n_updates        | 6940     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.5     |
# |    ep_rew_mean      | 28.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1121     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 29093    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0908   |
# |    n_updates        | 7023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.8     |
# |    ep_rew_mean      | 26.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1118     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 29374    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0332   |
# |    n_updates        | 7093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.6     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1118     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 29804    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0217   |
# |    n_updates        | 7200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.6     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1118     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 29852    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0132   |
# |    n_updates        | 7212     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.6     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1117     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 29900    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0043   |
# |    n_updates        | 7224     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.6     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1117     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 29948    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00144  |
# |    n_updates        | 7236     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.6     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# ...
# |    time_elapsed     | 91       |
# |    total_timesteps  | 97962    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00172  |
# |    n_updates        | 24240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 42.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3560     |
# |    fps              | 1073     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98010    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00118  |
# |    n_updates        | 24252    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 42.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3564     |
# |    fps              | 1073     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98058    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000136 |
# |    n_updates        | 24264    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 42.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3568     |
# |    fps              | 1073     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98106    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.21e-05 |
# |    n_updates        | 24276    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 42.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3572     |
# |    fps              | 1073     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98159    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0145   |
# |    n_updates        | 24289    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 42.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3576     |
# |    fps              | 1073     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98202    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00179  |
# |    n_updates        | 24300    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 44.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3580     |
# |    fps              | 1073     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98247    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00698  |
# |    n_updates        | 24311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 44.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3584     |
# |    fps              | 1073     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98294    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000198 |
# |    n_updates        | 24323    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 44.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3588     |
# |    fps              | 1072     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98343    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000117 |
# |    n_updates        | 24335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 44.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3592     |
# |    fps              | 1072     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98391    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.41e-05 |
# |    n_updates        | 24347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 44       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3596     |
# |    fps              | 1072     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98440    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.15e-06 |
# |    n_updates        | 24359    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 44.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3600     |
# |    fps              | 1072     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98487    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00446  |
# |    n_updates        | 24371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 44       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3604     |
# |    fps              | 1073     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98536    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00156  |
# |    n_updates        | 24383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 44       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3608     |
# |    fps              | 1073     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98587    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0107   |
# |    n_updates        | 24396    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 44       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3612     |
# |    fps              | 1073     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98630    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00189  |
# |    n_updates        | 24407    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 44       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3616     |
# |    fps              | 1073     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 98682    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00389  |
# |    n_updates        | 24420    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3620     |
# |    fps              | 1073     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 98731    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000734 |
# |    n_updates        | 24432    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3624     |
# |    fps              | 1073     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 98784    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00436  |
# |    n_updates        | 24445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 44.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3628     |
# |    fps              | 1072     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 98839    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00559  |
# |    n_updates        | 24459    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 44.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3632     |
# |    fps              | 1072     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 98890    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.431    |
# |    n_updates        | 24472    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 44.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3636     |
# |    fps              | 1072     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 98941    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.428    |
# |    n_updates        | 24485    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 44.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3640     |
# |    fps              | 1072     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 98984    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0283   |
# |    n_updates        | 24495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 44.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3644     |
# |    fps              | 1072     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 99031    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00759  |
# |    n_updates        | 24507    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 44.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3648     |
# |    fps              | 1072     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 99078    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000769 |
# |    n_updates        | 24519    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 44.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3652     |
# |    fps              | 1072     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 99127    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00218  |
# |    n_updates        | 24531    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 44.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3656     |
# |    fps              | 1072     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 99173    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00605  |
# |    n_updates        | 24543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 44.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3660     |
# |    fps              | 1072     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 99218    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00275  |
# |    n_updates        | 24554    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 42.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3664     |
# |    fps              | 1072     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 99456    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.468    |
# |    n_updates        | 24613    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 42.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3668     |
# |    fps              | 1072     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 99501    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.172    |
# |    n_updates        | 24625    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 41.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3672     |
# |    fps              | 1072     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 99662    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.407    |
# |    n_updates        | 24665    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 40.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3676     |
# |    fps              | 1072     |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 99780    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.107    |
# |    n_updates        | 24694    |
# ----------------------------------

# %%
# load (if needed)
# model = DQN.load("dqn_coverage", env=env)

mean_reward, std_reward = evaluate_policy(
    model, 
    env, 
    n_eval_episodes=20, 
    deterministic=True,
)
print(f"Mean reward: {mean_reward:.2f} ± {std_reward:.2f}")
# Out:
# Mean reward: 46.00 ± 0.00
# /home/joaolucasmbc/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
obs, _ = env.reset(seed=42)

for i in range(env.max_steps):
    # model.predict returns e.g. array([2], dtype=int64)
    action_arr, _ = model.predict(obs, deterministic=True)
    action = int(action_arr)       # unwrap to Python int
    print("step:", i, "action:", action)

    obs, reward, terminated, truncated, info = env.step(action)
    env.render()
    print("\n")

    if terminated or truncated:
        break
# Out:
# step: 0 action: 3
# ........
# .....A..
# ..TTT..#
# ..TTT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 1 action: 0
# ........
# ........
# ..TTTA.#
# ..TTT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 2 action: 3
# ........
# ........
# ..TTA..#
# ..TTT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 3 action: 0
# ........
# ........
# ..TTT..#
# ..TTA...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 4 action: 3
# ........
# ........
# ..TTT..#
# ..TAT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 5 action: 0
# ........
# ........
# ..TTT..#
# ..TTT...
# ..TA###.
# ....##..
# .###....
# ........
#
#
# step: 6 action: 3
# ........
# ........
# ..TTT..#
# ..TTT...
# ..AT###.
# ....##..
# .###....
# ........
#
#
# step: 7 action: 1
# ........
# ........
# ..TTT..#
# ..ATT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 8 action: 1
# ........
# ........
# ..ATT..#
# ..TTT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 9 action: 2
# ........
# ........
# ..TAT..#
# ..TTT...
# ..TT###.
# ....##..
# .###....
# ........

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# instantiate your env as before
env = CoverageEnv(seed=42)

# create the PPO model
model = PPO(
    policy="CnnPolicy",
    env=env,
    learning_rate=1e-4,         # often lower LR for PPO
    n_steps=2048,               # timesteps per rollout
    batch_size=64,              # minibatch size
    n_epochs=10,                # how many times to reuse each rollout
    gamma=0.99,
    policy_kwargs=dict(
        features_extractor_class=SmallCNN,
        features_extractor_kwargs=dict(features_dim=64),
        normalize_images=False, # your env already outputs float32 [0,1]
    ),
    verbose=1,
    device="cuda",              # send to GPU if available
)

# train for 500k timesteps
model.learn(total_timesteps=500_000)

# save it
model.save("ppo_coverage")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 160      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    fps             | 1410     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 165         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 1030        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012313096 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00867     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 34.7        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00669    |
# |    value_loss           | 79.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 163         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 978         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009797742 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00647     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 46.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00615    |
# |    value_loss           | 121         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -93.8        |
# | time/                   |              |
# |    fps                  | 952          |
# |    iterations           | 4            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0077655627 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -5.36e-06    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 48           |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00311     |
# |    value_loss           | 136          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | -96.9       |
# | time/                   |             |
# |    fps                  | 941         |
# |    iterations           | 5           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015129029 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 7.27e-06    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 105         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00328    |
# |    value_loss           | 158         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -93.7       |
# | time/                   |             |
# |    fps                  | 921         |
# |    iterations           | 6           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008144385 |
# |    clip_fraction        | 0.0141      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00542     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 61.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00321    |
# |    value_loss           | 109         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | -95.4       |
# | time/                   |             |
# |    fps                  | 898         |
# |    iterations           | 7           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010729138 |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 3.36e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 57.2        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00452    |
# |    value_loss           | 136         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 154          |
# |    ep_rew_mean          | -93.9        |
# | time/                   |              |
# |    fps                  | 885          |
# |    iterations           | 8            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0008282055 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.000442     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 46.3         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | 0.00123      |
# |    value_loss           | 136          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | -85.6        |
# | time/                   |              |
# |    fps                  | 882          |
# |    iterations           | 9            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0045205285 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 6.85e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 138          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 138          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | -89.4       |
# | time/                   |             |
# |    fps                  | 884         |
# |    iterations           | 10          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005311313 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.000554    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 39.5        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00282     |
# |    value_loss           | 144         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | -88.5        |
# | time/                   |              |
# |    fps                  | 879          |
# |    iterations           | 11           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0022798667 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.252        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 38.4         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 103          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | -89.4        |
# | time/                   |              |
# |    fps                  | 877          |
# |    iterations           | 12           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0024179346 |
# |    clip_fraction        | 0.00142      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.224        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 71.4         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000959    |
# |    value_loss           | 130          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 145          |
# |    ep_rew_mean          | -86.7        |
# | time/                   |              |
# |    fps                  | 880          |
# |    iterations           | 13           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0010206597 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.571        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 55.3         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000658    |
# |    value_loss           | 99.6         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 145           |
# |    ep_rew_mean          | -87.8         |
# | time/                   |               |
# |    fps                  | 881           |
# |    iterations           | 14            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00064315175 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.427         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 58.9          |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00106      |
# |    value_loss           | 124           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | -86.8       |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 15          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.003947731 |
# |    clip_fraction        | 0.000342    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 44.9        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00217    |
# |    value_loss           | 106         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 145          |
# |    ep_rew_mean          | -87.3        |
# | time/                   |              |
# |    fps                  | 876          |
# |    iterations           | 16           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0045182267 |
# |    clip_fraction        | 0.00239      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.39         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 34.9         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 85.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 145          |
# |    ep_rew_mean          | -86.8        |
# | time/                   |              |
# |    fps                  | 873          |
# |    iterations           | 17           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0005425877 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.443        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 33.9         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.000544     |
# |    value_loss           | 101          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | -85.5       |
# | time/                   |             |
# |    fps                  | 871         |
# |    iterations           | 18          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004580017 |
# |    clip_fraction        | 0.00527     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.703       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 19.9        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00305    |
# |    value_loss           | 62.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | -86.2       |
# | time/                   |             |
# |    fps                  | 870         |
# |    iterations           | 19          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005533324 |
# |    clip_fraction        | 0.00762     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 38.7        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 91          |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 26
#       8 model = PPO(
#       9     policy="CnnPolicy",
#      10     env=env,
#    (...)
#      22     device="cuda",              # send to GPU if available
#      23 )
#      25 # train for 500k timesteps
# ---> 26 model.learn(total_timesteps=500_000)
#      28 # save it
#      29 model.save("ppo_coverage")
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:324, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     321 assert self.env is not None
#     323 while self.num_timesteps < total_timesteps:
# --> 324     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     326     if not continue_training:
#     327         break
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:202, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     199 with th.no_grad():
#     200     # Convert to pytorch tensor or to TensorDict
#     201     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 202     actions, values, log_probs = self.policy(obs_tensor)
#     203 actions = actions.cpu().numpy()
#     205 # Rescale and perform action
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/common/policies.py:655, in ActorCriticPolicy.forward(self, obs, deterministic)
#     653 values = self.value_net(latent_vf)
#     654 distribution = self._get_action_dist_from_latent(latent_pi)
# --> 655 actions = distribution.get_actions(deterministic=deterministic)
#     656 log_prob = distribution.log_prob(actions)
#     657 actions = actions.reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/common/distributions.py:89, in Distribution.get_actions(self, deterministic)
#      87 if deterministic:
#      88     return self.mode()
# ---> 89 return self.sample()
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/common/distributions.py:298, in CategoricalDistribution.sample(self)
#     297 def sample(self) -> th.Tensor:
# --> 298     return self.distribution.sample()
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/torch/distributions/categorical.py:135, in Categorical.sample(self, sample_shape)
#     133     sample_shape = torch.Size(sample_shape)
#     134 probs_2d = self.probs.reshape(-1, self._num_events)
# --> 135 samples_2d = torch.multinomial(probs_2d, sample_shape.numel(), True).T
#     136 return samples_2d.reshape(self._extended_shape(sample_shape))
#
# KeyboardInterrupt:

# %%
mean_reward, std_reward = evaluate_policy(
    model, 
    env, 
    n_eval_episodes=20, 
    deterministic=True,
)
print(f"Mean reward: {mean_reward:.2f} ± {std_reward:.2f}")
# Out:
# Mean reward: -194.00 ± 0.00

# %%
obs, _ = env.reset(seed=42)

for i in range(env.max_steps):
    # model.predict returns e.g. array([2], dtype=int64)
    action_arr, _ = model.predict(obs, deterministic=True)
    action = int(action_arr)       # unwrap to Python int
    print("step:", i, "action:", action)

    obs, reward, terminated, truncated, info = env.step(action)
    env.render()
    print("\n")

    if terminated or truncated:
        break
# Out:
# step: 0 action: 0
# ........
# ........
# ..TTT.A#
# ..TTT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 1 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 2 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 3 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 4 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 5 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 6 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 7 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 8 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 9 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 10 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 11 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 12 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 13 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 14 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 15 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 16 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 17 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 18 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 19 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 20 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 21 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 22 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 23 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 24 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 25 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 26 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 27 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 28 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 29 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 30 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 31 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 32 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 33 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 34 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 35 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 36 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 37 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 38 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 39 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 40 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 41 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 42 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 43 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 44 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 45 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 46 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 47 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 48 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 49 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 50 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 51 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 52 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 53 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 54 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 55 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 56 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 57 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 58 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 59 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 60 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 61 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 62 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 63 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 64 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 65 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 66 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 67 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 68 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 69 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 70 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 71 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 72 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 73 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 74 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 75 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 76 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 77 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 78 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 79 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 80 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 81 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 82 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 83 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 84 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 85 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 86 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 87 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 88 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 89 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 90 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 91 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 92 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 93 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 94 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 95 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 96 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 97 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 98 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 99 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 100 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 101 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 102 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 103 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 104 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 105 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 106 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 107 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 108 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 109 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 110 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 111 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 112 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 113 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 114 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 115 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 116 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 117 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 118 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 119 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 120 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 121 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 122 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 123 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 124 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 125 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 126 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 127 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 128 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 129 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 130 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 131 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 132 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 133 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 134 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 135 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 136 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 137 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 138 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 139 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 140 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 141 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 142 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 143 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 144 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 145 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 146 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 147 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 148 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 149 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 150 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 151 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 152 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 153 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 154 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 155 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 156 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 157 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 158 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 159 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 160 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 161 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 162 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 163 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 164 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 165 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 166 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 167 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 168 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 169 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 170 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 171 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 172 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 173 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 174 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 175 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 176 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 177 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 178 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 179 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 180 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 181 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 182 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 183 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 184 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 185 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 186 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 187 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 188 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 189 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 190 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 191 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 192 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 193 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 194 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 195 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 196 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 197 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 198 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 199 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
