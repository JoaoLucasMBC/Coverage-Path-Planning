# %%
import numpy as np
import gymnasium as gym

from coverage_env import CoverageEnv

# %%
gym.register(
    id="Coverage-v0",
    entry_point="coverage_env:CoverageEnv",
    max_episode_steps=200,
)

# %%
import torch as th
import torch.nn as nn
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

class SmallCNN(BaseFeaturesExtractor):
    def __init__(self, observation_space, features_dim=64):
        super().__init__(observation_space, features_dim)
        n_channels, H, W = observation_space.shape

        # A tiny two‐layer CNN
        self.cnn = nn.Sequential(
            nn.Conv2d(n_channels, 16, kernel_size=3, stride=1),  # -> (16, H-2, W-2)
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=1),          # -> (32, H-4, W-4)
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with th.no_grad():
            sample = th.as_tensor(observation_space.sample()[None]).float()
            n_flatten = self.cnn(sample).shape[1]

        # Final linear layer to get exactly features_dim outputs
        self.linear = nn.Sequential(
            nn.Linear(n_flatten, features_dim),
            nn.ReLU(),
        )

    def forward(self, observations: th.Tensor) -> th.Tensor:
        return self.linear(self.cnn(observations))


class MediumCNN(BaseFeaturesExtractor):
    def __init__(self, observation_space, features_dim=64):
        super().__init__(observation_space, features_dim)
        n_channels, H, W = observation_space.shape

        self.cnn = nn.Sequential(
            nn.Conv2d(n_channels, 32, kernel_size=3, stride=1, padding=1),  # (32, H, W)
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),          # (64, H, W)
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.Flatten(),
        )

        # Compute flattened feature size
        with th.no_grad():
            sample = th.as_tensor(observation_space.sample()[None]).float()
            n_flatten = self.cnn(sample).shape[1]

        self.linear = nn.Sequential(
            nn.Linear(n_flatten, features_dim),
            nn.ReLU()
        )

    def forward(self, observations: th.Tensor) -> th.Tensor:
        return self.linear(self.cnn(observations))

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

# instantiate a single env (you can wrap VecEnv for parallelism later)
env = CoverageEnv(seed=42, curriculum=0)

# create the DQN model
model = DQN(
    policy="CnnPolicy",
    env=env,
    learning_starts=1000,
    buffer_size=500_000,
    learning_rate=1e-3,
    batch_size=32,
    gamma=0.99,
    exploration_fraction=0.3,
    exploration_final_eps=0.02,
    policy_kwargs=dict(
        features_extractor_class=MediumCNN,
        features_extractor_kwargs=dict(features_dim=64),
        normalize_images=False,    # since you already output float32 [0,1]
    ),
    verbose=1,
)

# train for 50k timesteps
model.learn(total_timesteps=200_000)

# save it
model.save("dqn_coverage")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | -148     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4655     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 726      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1117     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1399     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0532   |
# |    n_updates        | 99       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | -143     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 907      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2120     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0987   |
# |    n_updates        | 279      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | -144     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 870      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2813     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0987   |
# |    n_updates        | 453      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | -144     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 814      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3504     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00254  |
# |    n_updates        | 625      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | -146     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 721      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4254     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00982  |
# |    n_updates        | 813      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | -140     |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 683      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 4855     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00991  |
# |    n_updates        | 963      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 640      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 5461     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00648  |
# |    n_updates        | 1115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | -139     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 583      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 6198     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0105   |
# |    n_updates        | 1299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 580      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 6782     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00362  |
# |    n_updates        | 1445     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 168      |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 563      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 7372     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0228   |
# |    n_updates        | 1592     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 165      |
# |    ep_rew_mean      | -131     |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 572      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 7935     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00162  |
# |    n_updates        | 1733     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 164      |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 584      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 8504     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00258  |
# |    n_updates        | 1875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | -130     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 597      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 9155     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.92     |
# |    n_updates        | 2038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 608      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 9789     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00728  |
# |    n_updates        | 2197     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | -126     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 604      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 10335    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.191    |
# |    n_updates        | 2333     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -124     |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 606      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 10825    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.249    |
# |    n_updates        | 2456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -124     |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 594      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 11461    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0417   |
# |    n_updates        | 2615     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | -121     |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 596      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 11959    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0354   |
# |    n_updates        | 2739     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -119     |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 593      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 12432    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0329   |
# |    n_updates        | 2857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -114     |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 596      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 12689    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.26     |
# |    n_updates        | 2922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | -111     |
# |    exploration_rate | 0.786    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 582      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 13114    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0838   |
# |    n_updates        | 3028     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 582      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 13456    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.252    |
# |    n_updates        | 3113     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 147      |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 589      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 14072    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0244   |
# |    n_updates        | 3267     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.764    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 593      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 14444    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0785   |
# |    n_updates        | 3360     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | -103     |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 599      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 14918    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.161    |
# |    n_updates        | 3479     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -97.5    |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 601      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 15113    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0255   |
# |    n_updates        | 3528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -95.5    |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 606      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 15726    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0152   |
# |    n_updates        | 3681     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -93.3    |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 612      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 16285    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0783   |
# |    n_updates        | 3821     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 132      |
# |    ep_rew_mean      | -89.6    |
# |    exploration_rate | 0.728    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 615      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 16656    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0188   |
# |    n_updates        | 3913     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | -84.9    |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 618      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 17022    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0896   |
# |    n_updates        | 4005     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -82.3    |
# |    exploration_rate | 0.716    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 620      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 17395    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00872  |
# |    n_updates        | 4098     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 122      |
# |    ep_rew_mean      | -78      |
# |    exploration_rate | 0.712    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 621      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 17640    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0254   |
# |    n_updates        | 4159     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -71.4    |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 623      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 17826    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0118   |
# |    n_updates        | 4206     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -69.7    |
# |    exploration_rate | 0.702    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 623      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 18239    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0143   |
# |    n_updates        | 4309     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -67.9    |
# |    exploration_rate | 0.695    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 621      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 18696    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0587   |
# |    n_updates        | 4423     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -63.9    |
# |    exploration_rate | 0.691    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 610      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 18936    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0741   |
# |    n_updates        | 4483     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -59.7    |
# |    exploration_rate | 0.687    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 607      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 19151    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0276   |
# |    n_updates        | 4537     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -55.6    |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 609      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 19500    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.012    |
# |    n_updates        | 4624     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -52.9    |
# |    exploration_rate | 0.675    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 612      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 19919    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.572    |
# |    n_updates        | 4729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.4     |
# |    ep_rew_mean      | -50      |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 613      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 20173    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.741    |
# |    n_updates        | 4793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -46      |
# |    exploration_rate | 0.668    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 613      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 20333    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.79     |
# |    n_updates        | 4833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -41.2    |
# |    exploration_rate | 0.664    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 614      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 20559    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.14     |
# |    n_updates        | 4889     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.2     |
# |    ep_rew_mean      | -38.1    |
# |    exploration_rate | 0.661    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 615      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 20774    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.316    |
# |    n_updates        | 4943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.1     |
# |    ep_rew_mean      | -35.6    |
# |    exploration_rate | 0.656    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 616      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 21043    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.156    |
# |    n_updates        | 5010     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.1     |
# |    ep_rew_mean      | -35.7    |
# |    exploration_rate | 0.652    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 617      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 21302    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.257    |
# |    n_updates        | 5075     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.6     |
# |    ep_rew_mean      | -34.1    |
# |    exploration_rate | 0.648    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 618      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 21574    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.913    |
# |    n_updates        | 5143     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.9     |
# |    ep_rew_mean      | -32.5    |
# |    exploration_rate | 0.645    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 619      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 21749    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.292    |
# |    n_updates        | 5187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79       |
# |    ep_rew_mean      | -27.9    |
# |    exploration_rate | 0.641    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 621      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 21975    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.243    |
# |    n_updates        | 5243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.8     |
# |    ep_rew_mean      | -25.3    |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 621      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 22123    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.136    |
# |    n_updates        | 5280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.4     |
# |    ep_rew_mean      | -22.6    |
# |    exploration_rate | 0.635    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 622      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 22357    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.197    |
# |    n_updates        | 5339     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.4     |
# |    ep_rew_mean      | -22.7    |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 623      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 22557    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.128    |
# |    n_updates        | 5389     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.7     |
# |    ep_rew_mean      | -18.6    |
# |    exploration_rate | 0.628    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 624      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 22800    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.138    |
# |    n_updates        | 5449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.7     |
# |    ep_rew_mean      | -14.3    |
# |    exploration_rate | 0.625    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 625      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 22958    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.173    |
# |    n_updates        | 5489     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.8     |
# |    ep_rew_mean      | -11.9    |
# |    exploration_rate | 0.622    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 625      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 23137    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.123    |
# |    n_updates        | 5534     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.5     |
# |    ep_rew_mean      | -9.57    |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 626      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 23268    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0795   |
# |    n_updates        | 5566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 59.9     |
# |    ep_rew_mean      | -6.96    |
# |    exploration_rate | 0.618    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 626      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 23380    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0791   |
# |    n_updates        | 5594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.1     |
# |    ep_rew_mean      | -7.18    |
# |    exploration_rate | 0.614    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 622      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 23647    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0979   |
# |    n_updates        | 5661     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.2     |
# |    ep_rew_mean      | -7.31    |
# |    exploration_rate | 0.611    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 622      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 23846    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.595    |
# |    n_updates        | 5711     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.8     |
# |    ep_rew_mean      | -4.47    |
# |    exploration_rate | 0.608    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 621      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 24020    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.167    |
# |    n_updates        | 5754     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.4     |
# |    ep_rew_mean      | -0.76    |
# |    exploration_rate | 0.606    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 620      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 24139    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.139    |
# |    n_updates        | 5784     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54       |
# |    ep_rew_mean      | -0.31    |
# |    exploration_rate | 0.603    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 620      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 24334    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.112    |
# |    n_updates        | 5833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.1     |
# |    ep_rew_mean      | 0.52     |
# |    exploration_rate | 0.6      |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 620      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 24466    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.272    |
# |    n_updates        | 5866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.9     |
# |    ep_rew_mean      | 1.75     |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 618      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 24692    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.373    |
# |    n_updates        | 5922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49.9     |
# |    ep_rew_mean      | 4.09     |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 616      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 24910    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.323    |
# |    n_updates        | 5977     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.9     |
# |    ep_rew_mean      | 5.08     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 614      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 25065    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.149    |
# |    n_updates        | 6016     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.1     |
# |    ep_rew_mean      | 5.88     |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 613      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 25145    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.175    |
# |    n_updates        | 6036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46.9     |
# |    ep_rew_mean      | 7.1      |
# |    exploration_rate | 0.588    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 612      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 25249    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0806   |
# |    n_updates        | 6062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46.5     |
# |    ep_rew_mean      | 7.55     |
# |    exploration_rate | 0.585    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 611      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 25419    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.238    |
# |    n_updates        | 6104     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.1     |
# |    ep_rew_mean      | 8.94     |
# |    exploration_rate | 0.583    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 610      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 25549    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.137    |
# |    n_updates        | 6137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.6     |
# |    ep_rew_mean      | 9.43     |
# |    exploration_rate | 0.579    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 608      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 25759    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.122    |
# |    n_updates        | 6189     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.577    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 608      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 25921    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.877    |
# |    n_updates        | 6230     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.1     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.574    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 609      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 26055    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0548   |
# |    n_updates        | 6263     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.1     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.572    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 609      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 26183    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.394    |
# |    n_updates        | 6295     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.8     |
# |    ep_rew_mean      | 12.2     |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 610      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 26306    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0865   |
# |    n_updates        | 6326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.2     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.568    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 610      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 26479    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.165    |
# |    n_updates        | 6369     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.2     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.566    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 610      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 26577    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.239    |
# |    n_updates        | 6394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39       |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.564    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 609      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 26702    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0843   |
# |    n_updates        | 6425     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.7     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.56     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 610      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 26925    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.909    |
# |    n_updates        | 6481     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.5     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.556    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 608      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 27187    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.843    |
# |    n_updates        | 6546     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.1     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.553    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 607      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 27374    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.129    |
# |    n_updates        | 6593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.6     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.549    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 606      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 27638    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.818    |
# |    n_updates        | 6659     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.9     |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 605      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 27733    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.174    |
# |    n_updates        | 6683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.4     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 604      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 27885    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.263    |
# |    n_updates        | 6721     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.7     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.543    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 603      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 27994    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.247    |
# |    n_updates        | 6748     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.9     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.54     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 601      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 28133    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.332    |
# |    n_updates        | 6783     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.7     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.536    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 599      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 28406    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.188    |
# |    n_updates        | 6851     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.7     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 598      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 28532    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.494    |
# |    n_updates        | 6882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40       |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.531    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 598      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 28689    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.219    |
# |    n_updates        | 6922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.5     |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.529    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 598      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 28859    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.123    |
# |    n_updates        | 6964     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.6     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 597      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 29026    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.136    |
# |    n_updates        | 7006     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.1     |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.524    |
# | time/               |          |
# |    episodes         | 368      |
# ...
# |    episodes         | 1052     |
# |    fps              | 507      |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 76368    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.558    |
# |    n_updates        | 18841    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1056     |
# |    fps              | 508      |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 77168    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.614    |
# |    n_updates        | 19041    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 507      |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 77968    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.52     |
# |    n_updates        | 19241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 168      |
# |    ep_rew_mean      | -139     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1064     |
# |    fps              | 507      |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 78701    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.603    |
# |    n_updates        | 19425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | -143     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1068     |
# |    fps              | 506      |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 79501    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.668    |
# |    n_updates        | 19625    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | -144     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1072     |
# |    fps              | 506      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 80301    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.54     |
# |    n_updates        | 19825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | -144     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1076     |
# |    fps              | 506      |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 81101    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.33     |
# |    n_updates        | 20025    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | -150     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 507      |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 81901    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.13     |
# |    n_updates        | 20225    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -154     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1084     |
# |    fps              | 507      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 82701    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.966    |
# |    n_updates        | 20425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | -158     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1088     |
# |    fps              | 508      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 83501    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.65     |
# |    n_updates        | 20625    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 508      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 84256    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.09     |
# |    n_updates        | 20813    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 509      |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 85056    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.733    |
# |    n_updates        | 21013    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 509      |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 85856    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.26     |
# |    n_updates        | 21213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 509      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 86656    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.753    |
# |    n_updates        | 21413    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 509      |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 87357    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.453    |
# |    n_updates        | 21589    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 510      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 88157    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.6      |
# |    n_updates        | 21789    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 510      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 88831    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.649    |
# |    n_updates        | 21957    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 510      |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 89631    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.97     |
# |    n_updates        | 22157    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 510      |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 90431    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.06     |
# |    n_updates        | 22357    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 510      |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 91231    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.03     |
# |    n_updates        | 22557    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 510      |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 92031    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.808    |
# |    n_updates        | 22757    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 510      |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 92716    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.551    |
# |    n_updates        | 22928    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 510      |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 93516    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.726    |
# |    n_updates        | 23128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 509      |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 94316    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.291    |
# |    n_updates        | 23328    |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 27
#       8 model = DQN(
#       9     policy="CnnPolicy",
#      10     env=env,
#    (...)
#      23     verbose=1,
#      24 )
#      26 # train for 50k timesteps
# ---> 27 model.learn(total_timesteps=200_000)
#      29 # save it
#      30 model.save("dqn_coverage")
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/dqn/dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/dqn/dqn.py:217, in DQN.train(self, gradient_steps, batch_size)
#     215 # Optimize the policy
#     216 self.policy.optimizer.zero_grad()
# --> 217 loss.backward()
#     218 # Clip gradient norm
#     219 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/torch/_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)
#     646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/torch/autograd/__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
#     351 # some Python versions print out the first line of a multi-line function
#     352 # calls in the traceback and some print out the last line
# --> 353 _engine_run_backward(
#     354     tensors,
#     355     grad_tensors_,
#     356     retain_graph,
#     357     create_graph,
#     358     inputs,
#     359     allow_unreachable=True,
#     360     accumulate_grad=True,
#     361 )
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/torch/autograd/graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# load (if needed)
# model = DQN.load("dqn_coverage", env=env)

mean_reward, std_reward = evaluate_policy(
    model, 
    env, 
    n_eval_episodes=20, 
    deterministic=True,
)
print(f"Mean reward: {mean_reward:.2f} ± {std_reward:.2f}")
# Out:
# /home/joaolucasmbc/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward: -182.00 ± 4.65

# %%
obs, _ = env.reset()

for i in range(env.max_steps):
    # model.predict returns e.g. array([2], dtype=int64)
    action_arr, _ = model.predict(obs, deterministic=True)
    action = int(action_arr)       # unwrap to Python int
    print("step:", i, "action:", action)

    obs, reward, terminated, truncated, info = env.step(action)
    env.render()
    print("\n")

    if terminated or truncated:
        break
# Out:
# step: 0 action: 0
# ........
# ........
# A...TTT.
# ....#TT.
# ....TTT.
# ........
# ........
# ........
#
#
# step: 1 action: 2
# ........
# ........
# .A..TTT.
# ....#TT.
# ....TTT.
# ........
# ........
# ........
#
#
# step: 2 action: 2
# ........
# ........
# ..A.TTT.
# ....#TT.
# ....TTT.
# ........
# ........
# ........
#
#
# step: 3 action: 2
# ........
# ........
# ...ATTT.
# ....#TT.
# ....TTT.
# ........
# ........
# ........
#
#
# step: 4 action: 2
# ........
# ........
# ....ATT.
# ....#TT.
# ....TTT.
# ........
# ........
# ........
#
#
# step: 5 action: 2
# ........
# ........
# ....TAT.
# ....#TT.
# ....TTT.
# ........
# ........
# ........
#
#
# step: 6 action: 2
# ........
# ........
# ....TTA.
# ....#TT.
# ....TTT.
# ........
# ........
# ........
#
#
# step: 7 action: 3
# ........
# ........
# ....TAT.
# ....#TT.
# ....TTT.
# ........
# ........
# ........
#
#
# step: 8 action: 0
# ........
# ........
# ....TTT.
# ....#AT.
# ....TTT.
# ........
# ........
# ........
#
#
# step: 9 action: 0
# ........
# ........
# ....TTT.
# ....#TT.
# ....TAT.
# ........
# ........
# ........
#
#
# step: 10 action: 3
# ........
# ........
# ....TTT.
# ....#TT.
# ....ATT.
# ........
# ........
# ........
#
#
# step: 11 action: 2
# ........
# ........
# ....TTT.
# ....#TT.
# ....TAT.
# ........
# ........
# ........
#
#
# step: 12 action: 2
# ........
# ........
# ....TTT.
# ....#TT.
# ....TTA.
# ........
# ........
# ........
#
#
# step: 13 action: 1
# ........
# ........
# ....TTT.
# ....#TA.
# ....TTT.
# ........
# ........
# ........

# %% [markdown]
# # **PPO**

# %%
class SimplerCNN(BaseFeaturesExtractor):
    def __init__(self, observation_space, features_dim=64):
        super().__init__(observation_space, features_dim)
        n_input_channels = observation_space.shape[0]

        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
        )

        with th.no_grad():
            sample = th.as_tensor(observation_space.sample()[None]).float()
            n_flatten = self.cnn(sample).shape[1]

        self.linear = nn.Sequential(
            nn.Linear(n_flatten, features_dim),
            nn.ReLU(),
        )

    def forward(self, observations: th.Tensor) -> th.Tensor:
        return self.linear(self.cnn(observations))

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# instantiate your env as before
env = CoverageEnv(seed=42)

# create the PPO model
model = PPO(
    policy="CnnPolicy",
    env=env,
    learning_rate=1e-4,         # often lower LR for PPO
    n_steps=256,               # timesteps per rollout
    batch_size=32,              # minibatch size
    n_epochs=10,                # how many times to reuse each rollout
    gamma=0.99,
    ent_coef=0.01,  # or try 0.005 if too random
    policy_kwargs=dict(
        features_extractor_class=SimplerCNN,
        features_extractor_kwargs=dict(features_dim=64),
        normalize_images=False, # your env already outputs float32 [0,1]
    ),
    verbose=1,
    device="cuda",              # send to GPU if available
)

# train for 500k timesteps
model.learn(total_timesteps=1_500_000)

# save it
model.save("ppo_coverage")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95       |
# |    ep_rew_mean     | -41      |
# | time/              |          |
# |    fps             | 631      |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 256      |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | -137         |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0042865165 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0117       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 60.1         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00526     |
# |    value_loss           | 151          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 320         |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.001861173 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.058       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 56          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00261    |
# |    value_loss           | 127         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | -105         |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 4            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0050821113 |
# |    clip_fraction        | 0.023        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00242      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 84.4         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00545     |
# |    value_loss           | 163          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 148          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 341          |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1280         |
# | train/                  |              |
# |    approx_kl            | 0.0023795064 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0454       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 76           |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00317     |
# |    value_loss           | 167          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 6            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 0.0019696648 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0333       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 46.7         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 116          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 7           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.003480235 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0107      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 111         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00304    |
# |    value_loss           | 201         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 149          |
# |    ep_rew_mean          | -106         |
# | time/                   |              |
# |    fps                  | 308          |
# |    iterations           | 8            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0066817235 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00311      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 80.9         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00516     |
# |    value_loss           | 170          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 152          |
# |    ep_rew_mean          | -113         |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 9            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 2304         |
# | train/                  |              |
# |    approx_kl            | 0.0020575002 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.033        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 73.6         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00357     |
# |    value_loss           | 154          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 149          |
# |    ep_rew_mean          | -110         |
# | time/                   |              |
# |    fps                  | 305          |
# |    iterations           | 10           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0019739543 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -2.43e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 80.4         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 163          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -118        |
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 11          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.007896859 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.000811    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 49.4        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00892    |
# |    value_loss           | 144         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | -121         |
# | time/                   |              |
# |    fps                  | 310          |
# |    iterations           | 12           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0020671433 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000872     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 53.9         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00393     |
# |    value_loss           | 134          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 159          |
# |    ep_rew_mean          | -124         |
# | time/                   |              |
# |    fps                  | 303          |
# |    iterations           | 13           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 3328         |
# | train/                  |              |
# |    approx_kl            | 0.0026694683 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -4.4e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 69           |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00391     |
# |    value_loss           | 151          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | -129         |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 14           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0026434765 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 8.29e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 44.8         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00334     |
# |    value_loss           | 113          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 165         |
# |    ep_rew_mean          | -132        |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 15          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.006016708 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.000183    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 64.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00868    |
# |    value_loss           | 139         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | -130         |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 16           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0063938177 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -3e-05       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 67           |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00874     |
# |    value_loss           | 148          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 164          |
# |    ep_rew_mean          | -130         |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 17           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 4352         |
# | train/                  |              |
# |    approx_kl            | 0.0035997177 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -9.2e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 83.7         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 171          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | -132         |
# | time/                   |              |
# |    fps                  | 305          |
# |    iterations           | 18           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 0.0036941392 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 4.99e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 62.3         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 143          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 168         |
# |    ep_rew_mean          | -135        |
# | time/                   |             |
# |    fps                  | 309         |
# |    iterations           | 19          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 4864        |
# | train/                  |             |
# |    approx_kl            | 0.005202853 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.000102   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 57.5        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00711    |
# |    value_loss           | 132         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 169         |
# |    ep_rew_mean          | -137        |
# | time/                   |             |
# |    fps                  | 312         |
# |    iterations           | 20          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.001645098 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -5.48e-06   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 69.1        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00193    |
# |    value_loss           | 125         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | -139        |
# | time/                   |             |
# |    fps                  | 316         |
# |    iterations           | 21          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 5376        |
# | train/                  |             |
# |    approx_kl            | 0.009307094 |
# |    clip_fraction        | 0.00195     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -1.6e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 72          |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 146         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 170           |
# |    ep_rew_mean          | -139          |
# | time/                   |               |
# |    fps                  | 319           |
# |    iterations           | 22            |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 5632          |
# | train/                  |               |
# |    approx_kl            | 0.00068111764 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 4.15e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 51.9          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.0011       |
# |    value_loss           | 112           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 23           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 5888         |
# | train/                  |              |
# |    approx_kl            | 0.0064865947 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 1.11e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 77.9         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00548     |
# |    value_loss           | 162          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 173        |
# |    ep_rew_mean          | -142       |
# | time/                   |            |
# |    fps                  | 324        |
# |    iterations           | 24         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00681094 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 2.8e-06    |
# |    learning_rate        | 0.0001     |
# |    loss                 | 58.6       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00813   |
# |    value_loss           | 125        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 326          |
# |    iterations           | 25           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0074505787 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 7.87e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 53.6         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00683     |
# |    value_loss           | 123          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 174          |
# |    ep_rew_mean          | -143         |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 26           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0027687736 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 2.22e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 48.5         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 167          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 171          |
# |    ep_rew_mean          | -139         |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 27           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 6912         |
# | train/                  |              |
# |    approx_kl            | 0.0013937266 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -5.29e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 51.1         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 116          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 172       |
# |    ep_rew_mean          | -140      |
# | time/                   |           |
# |    fps                  | 330       |
# |    iterations           | 28        |
# |    time_elapsed         | 21        |
# |    total_timesteps      | 7168      |
# | train/                  |           |
# |    approx_kl            | 0.0158662 |
# |    clip_fraction        | 0.202     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.38     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 166       |
# |    n_updates            | 270       |
# |    policy_gradient_loss | -0.0169   |
# |    value_loss           | 223       |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 29           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 7424         |
# | train/                  |              |
# |    approx_kl            | 0.0011012312 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.000127    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 49.8         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000732    |
# |    value_loss           | 117          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 174           |
# |    ep_rew_mean          | -143          |
# | time/                   |               |
# |    fps                  | 326           |
# |    iterations           | 30            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 0.00020021084 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.000428      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 53.2          |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000762     |
# |    value_loss           | 114           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 171           |
# |    ep_rew_mean          | -140          |
# | time/                   |               |
# |    fps                  | 325           |
# |    iterations           | 31            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 7936          |
# | train/                  |               |
# |    approx_kl            | 0.00051415106 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 3.36e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 51.1          |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.00144      |
# |    value_loss           | 104           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 32           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0049172146 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -5.6e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 51.8         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00315     |
# |    value_loss           | 196          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 172           |
# |    ep_rew_mean          | -142          |
# | time/                   |               |
# |    fps                  | 324           |
# |    iterations           | 33            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 8448          |
# | train/                  |               |
# |    approx_kl            | 0.00047338195 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -3.99e-05     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 61.4          |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.00138      |
# |    value_loss           | 133           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 173          |
# |    ep_rew_mean          | -144         |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 34           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0016653829 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -3.99e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 57.3         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00364     |
# |    value_loss           | 115          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 174          |
# |    ep_rew_mean          | -145         |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 35           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 8960         |
# | train/                  |              |
# |    approx_kl            | 0.0020887488 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 1.22e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 50.6         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00349     |
# |    value_loss           | 97.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 174         |
# |    ep_rew_mean          | -144        |
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 36          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.006655285 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0001      |
# |    loss                 | 50.8        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00961    |
# |    value_loss           | 106         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 174          |
# |    ep_rew_mean          | -145         |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 37           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 9472         |
# | train/                  |              |
# |    approx_kl            | 0.0024151877 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 1.79e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 93.9         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 185          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 175           |
# |    ep_rew_mean          | -145          |
# | time/                   |               |
# |    fps                  | 324           |
# |    iterations           | 38            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 0.00045015616 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 8.46e-06      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 44            |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.00138      |
# |    value_loss           | 101           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 174         |
# |    ep_rew_mean          | -144        |
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 39          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 9984        |
# | train/                  |             |
# |    approx_kl            | 0.000923635 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 1.55e-06    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 43.4        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 91.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 174         |
# |    ep_rew_mean          | -144        |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 40          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019027635 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 1.49e-06    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 85.6        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 256         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 175           |
# |    ep_rew_mean          | -145          |
# | time/                   |               |
# |    fps                  | 329           |
# |    iterations           | 41            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 10496         |
# | train/                  |               |
# |    approx_kl            | 0.00047495496 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 5.96e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 42.8          |
# |    n_updates            | 400           |
# |    policy_gradient_loss | 0.0012        |
# |    value_loss           | 95.3          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 174           |
# |    ep_rew_mean          | -144          |
# | time/                   |               |
# |    fps                  | 330           |
# |    iterations           | 42            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 10752         |
# | train/                  |               |
# |    approx_kl            | 0.00038934452 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 9.83e-06      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 42.2          |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.00152      |
# |    value_loss           | 93.8          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 174         |
# |    ep_rew_mean          | -145        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 43          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 11008       |
# | train/                  |             |
# |    approx_kl            | 0.004611681 |
# |    clip_fraction        | 0.00625     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 2.98e-06    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 68.9        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00419    |
# |    value_loss           | 155         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 172           |
# |    ep_rew_mean          | -141          |
# | time/                   |               |
# |    fps                  | 332           |
# |    iterations           | 44            |
# |    time_elapsed         | 33            |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 0.00024136505 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.000159      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 42.2          |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.00143      |
# |    value_loss           | 87            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 45           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 11520        |
# | train/                  |              |
# |    approx_kl            | 0.0017506985 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 8.94e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 182          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 270          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 46           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 0.0059350394 |
# |    clip_fraction        | 0.00977      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 4.77e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 93.3         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000206    |
# |    value_loss           | 253          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 47          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 12032       |
# | train/                  |             |
# |    approx_kl            | 0.006480267 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 43.4        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00853    |
# |    value_loss           | 89.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 173          |
# |    ep_rew_mean          | -142         |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 48           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0008648501 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 6.28e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 36.5         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 83.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 171          |
# |    ep_rew_mean          | -139         |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 49           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 12544        |
# | train/                  |              |
# |    approx_kl            | 0.0036696873 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000139     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 52.5         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00258     |
# |    value_loss           | 183          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 50          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.001041031 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00781     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 46.7        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00175     |
# |    value_loss           | 149         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 169          |
# |    ep_rew_mean          | -138         |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 51           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 13056        |
# | train/                  |              |
# |    approx_kl            | 0.0006289948 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.541        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 9.36         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000568    |
# |    value_loss           | 33.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 170          |
# |    ep_rew_mean          | -138         |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 52           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0001727331 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.298        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 25.3         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 0.000419     |
# |    value_loss           | 132          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 170           |
# |    ep_rew_mean          | -139          |
# | time/                   |               |
# |    fps                  | 333           |
# |    iterations           | 53            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 13568         |
# | train/                  |               |
# |    approx_kl            | 0.00026900903 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.69          |
# |    learning_rate        | 0.0001        |
# |    loss                 | 11.9          |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -0.000402     |
# |    value_loss           | 27.3          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 171           |
# |    ep_rew_mean          | -139          |
# | time/                   |               |
# |    fps                  | 333           |
# |    iterations           | 54            |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 13824         |
# | train/                  |               |
# |    approx_kl            | 0.00043505407 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.788         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 20.3          |
# |    n_updates            | 530           |
# ...
# |    approx_kl            | 0.0059125237 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.056        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 40.1         |
# |    n_updates            | 4010         |
# |    policy_gradient_loss | 0.00553      |
# |    value_loss           | 93.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 403         |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 103168      |
# | train/                  |             |
# |    approx_kl            | 0.013831737 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.591       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.57        |
# |    n_updates            | 4020        |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 12.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 161         |
# |    ep_rew_mean          | -123        |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 404         |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 103424      |
# | train/                  |             |
# |    approx_kl            | 0.006927352 |
# |    clip_fraction        | 0.0172      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 40.7        |
# |    n_updates            | 4030        |
# |    policy_gradient_loss | -0.00501    |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 405         |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 103680      |
# | train/                  |             |
# |    approx_kl            | 0.013549151 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.252       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.493       |
# |    n_updates            | 4040        |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 15.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 159        |
# |    ep_rew_mean          | -121       |
# | time/                   |            |
# |    fps                  | 329        |
# |    iterations           | 406        |
# |    time_elapsed         | 315        |
# |    total_timesteps      | 103936     |
# | train/                  |            |
# |    approx_kl            | 0.00984623 |
# |    clip_fraction        | 0.0539     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.101      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 18.9       |
# |    n_updates            | 4050       |
# |    policy_gradient_loss | -0.00469   |
# |    value_loss           | 158        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 158        |
# |    ep_rew_mean          | -120       |
# | time/                   |            |
# |    fps                  | 330        |
# |    iterations           | 407        |
# |    time_elapsed         | 315        |
# |    total_timesteps      | 104192     |
# | train/                  |            |
# |    approx_kl            | 0.00669383 |
# |    clip_fraction        | 0.0383     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.283      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 83.9       |
# |    n_updates            | 4060       |
# |    policy_gradient_loss | -0.00707   |
# |    value_loss           | 142        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 408         |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.008488539 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.214       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 22.1        |
# |    n_updates            | 4070        |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 115         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 159          |
# |    ep_rew_mean          | -121         |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 409          |
# |    time_elapsed         | 317          |
# |    total_timesteps      | 104704       |
# | train/                  |              |
# |    approx_kl            | 0.0090665715 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.74         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.98         |
# |    n_updates            | 4080         |
# |    policy_gradient_loss | -0.00344     |
# |    value_loss           | 15.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 410         |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 104960      |
# | train/                  |             |
# |    approx_kl            | 0.011750019 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.0844      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 98.6        |
# |    n_updates            | 4090        |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 158         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | -122         |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 411          |
# |    time_elapsed         | 318          |
# |    total_timesteps      | 105216       |
# | train/                  |              |
# |    approx_kl            | 0.0053553917 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.138       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 113          |
# |    n_updates            | 4100         |
# |    policy_gradient_loss | 0.000173     |
# |    value_loss           | 165          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | -123         |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 412          |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 105472       |
# | train/                  |              |
# |    approx_kl            | 0.0116701145 |
# |    clip_fraction        | 0.0977       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.375        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.32         |
# |    n_updates            | 4110         |
# |    policy_gradient_loss | -0.00732     |
# |    value_loss           | 62.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 413         |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 105728      |
# | train/                  |             |
# |    approx_kl            | 0.017236248 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.049       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 25.5        |
# |    n_updates            | 4120        |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 83          |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 27
#       8 model = PPO(
#       9     policy="CnnPolicy",
#      10     env=env,
#    (...)
#      23     device="cuda",              # send to GPU if available
#      24 )
#      26 # train for 500k timesteps
# ---> 27 model.learn(total_timesteps=1_500_000)
#      29 # save it
#      30 model.save("ppo_coverage")
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:337, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     334         assert self.ep_info_buffer is not None
#     335         self.dump_logs(iteration)
# --> 337     self.train()
#     339 callback.on_training_end()
#     341 return self
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:278, in PPO.train(self)
#     276     # Clip grad norm
#     277     th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
# --> 278     self.policy.optimizer.step()
#     280 self._n_updates += 1
#     281 if not continue_training:
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/torch/optim/optimizer.py:485, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     480         else:
#     481             raise RuntimeError(
#     482                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     483             )
# --> 485 out = func(*args, **kwargs)
#     486 self._optimizer_step_code()
#     488 # call optimizer step post hooks
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/torch/optim/optimizer.py:79, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      77     torch.set_grad_enabled(self.defaults["differentiable"])
#      78     torch._dynamo.graph_break()
# ---> 79     ret = func(self, *args, **kwargs)
#      80 finally:
#      81     torch._dynamo.graph_break()
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/torch/optim/adam.py:246, in Adam.step(self, closure)
#     234     beta1, beta2 = group["betas"]
#     236     has_complex = self._init_group(
#     237         group,
#     238         params_with_grad,
#    (...)
#     243         state_steps,
#     244     )
# --> 246     adam(
#     247         params_with_grad,
#     248         grads,
#     249         exp_avgs,
#     250         exp_avg_sqs,
#     251         max_exp_avg_sqs,
#     252         state_steps,
#     253         amsgrad=group["amsgrad"],
#     254         has_complex=has_complex,
#     255         beta1=beta1,
#     256         beta2=beta2,
#     257         lr=group["lr"],
#     258         weight_decay=group["weight_decay"],
#     259         eps=group["eps"],
#     260         maximize=group["maximize"],
#     261         foreach=group["foreach"],
#     262         capturable=group["capturable"],
#     263         differentiable=group["differentiable"],
#     264         fused=group["fused"],
#     265         grad_scale=getattr(self, "grad_scale", None),
#     266         found_inf=getattr(self, "found_inf", None),
#     267         decoupled_weight_decay=group["decoupled_weight_decay"],
#     268     )
#     270 return loss
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/torch/optim/optimizer.py:147, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     145     return disabled_func(*args, **kwargs)
#     146 else:
# --> 147     return func(*args, **kwargs)
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/torch/optim/adam.py:933, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     930 else:
#     931     func = _single_tensor_adam
# --> 933 func(
#     934     params,
#     935     grads,
#     936     exp_avgs,
#     937     exp_avg_sqs,
#     938     max_exp_avg_sqs,
#     939     state_steps,
#     940     amsgrad=amsgrad,
#     941     has_complex=has_complex,
#     942     beta1=beta1,
#     943     beta2=beta2,
#     944     lr=lr,
#     945     weight_decay=weight_decay,
#     946     eps=eps,
#     947     maximize=maximize,
#     948     capturable=capturable,
#     949     differentiable=differentiable,
#     950     grad_scale=grad_scale,
#     951     found_inf=found_inf,
#     952     decoupled_weight_decay=decoupled_weight_decay,
#     953 )
#
# File ~/mambaforge/envs/rl-cpp/lib/python3.10/site-packages/torch/optim/adam.py:761, in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     759 torch._foreach_div_(exp_avg_sq_sqrt, bias_correction2_sqrt)
#     760 torch._foreach_add_(exp_avg_sq_sqrt, eps)
# --> 761 torch._foreach_addcdiv_(
#     762     device_params, device_exp_avgs, exp_avg_sq_sqrt, step_size  # type: ignore[arg-type]
#     763 )
#
# KeyboardInterrupt:

# %%
mean_reward, std_reward = evaluate_policy(
    model, 
    env, 
    n_eval_episodes=20, 
    deterministic=True,
)
print(f"Mean reward: {mean_reward:.2f} ± {std_reward:.2f}")
# Out:
# Mean reward: -194.00 ± 0.00

# %%
obs, _ = env.reset(seed=42)

for i in range(env.max_steps):
    # model.predict returns e.g. array([2], dtype=int64)
    action_arr, _ = model.predict(obs, deterministic=True)
    action = int(action_arr)       # unwrap to Python int
    print("step:", i, "action:", action)

    obs, reward, terminated, truncated, info = env.step(action)
    env.render()
    print("\n")

    if terminated or truncated:
        break
# Out:
# step: 0 action: 0
# ........
# ........
# ..TTT.A#
# ..TTT...
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 1 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 2 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 3 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 4 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 5 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 6 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 7 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 8 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 9 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 10 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 11 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 12 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 13 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 14 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 15 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 16 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 17 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 18 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 19 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 20 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 21 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 22 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 23 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 24 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 25 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 26 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 27 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 28 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 29 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 30 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 31 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 32 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 33 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 34 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 35 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 36 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 37 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 38 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 39 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 40 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 41 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 42 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 43 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 44 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 45 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 46 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 47 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 48 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 49 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 50 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 51 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 52 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 53 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 54 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 55 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 56 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 57 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 58 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 59 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 60 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 61 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 62 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 63 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 64 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 65 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 66 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 67 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 68 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 69 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 70 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 71 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 72 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 73 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 74 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 75 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 76 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 77 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 78 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 79 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 80 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 81 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 82 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 83 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 84 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 85 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 86 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 87 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 88 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 89 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 90 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 91 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 92 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 93 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 94 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 95 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 96 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 97 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 98 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 99 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 100 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 101 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 102 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 103 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 104 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 105 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 106 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 107 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 108 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 109 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 110 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 111 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 112 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 113 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 114 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 115 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 116 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 117 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 118 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 119 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 120 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 121 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 122 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 123 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 124 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 125 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 126 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 127 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 128 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 129 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 130 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 131 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 132 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 133 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 134 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 135 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 136 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 137 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 138 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 139 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 140 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 141 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 142 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 143 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 144 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 145 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 146 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 147 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 148 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 149 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 150 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 151 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 152 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 153 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 154 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 155 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 156 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 157 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 158 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 159 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 160 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 161 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 162 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 163 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 164 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 165 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 166 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 167 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 168 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 169 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 170 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 171 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 172 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 173 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 174 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 175 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 176 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 177 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 178 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 179 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 180 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 181 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 182 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 183 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 184 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 185 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 186 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 187 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 188 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 189 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 190 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 191 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 192 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 193 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 194 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 195 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 196 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 197 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 198 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
#
#
# step: 199 action: 0
# ........
# ........
# ..TTT..#
# ..TTT.A.
# ..TT###.
# ....##..
# .###....
# ........
